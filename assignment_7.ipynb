# %% [markdown]
# Before you turn this assignment in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says "YOUR ANSWER HERE" or `YOUR CODE HERE` and remove the `raise NotImplementedError()` lines.
#
# Code blocks starting with a `# tests` comment provide unit tests which have to run without errors in order to get full points. Be aware that there might be further 'secret' tests to check correct implementation! I.e. the provided unit tests are necessary but not sufficient for full points!
#
# You are always welcome to add **additional plots, tests, or debug outputs**.
# However, make sure to: **1) not break the automated tests**, and **2) switch off any excessive debug output** when you submit your notebook!
#
# Please add your name and student ID below:

# %%
NAME = "Marko Kadic"
STUDENT_ID = "12045128"

# %%
assert len(NAME) > 0, "Enter your name!"
assert len(STUDENT_ID) > 0, "Enter your student ID!"

# %% [markdown]
# # Intelligent Audio and Music Analysis Assignment 7
#
# This assignment accounts for the last 50 points of the 3rd and last assignment block (100 points total)
#
# Assignment is mainly **free form**, the goal is to apply what has been practiced so far. For implementing assignment 7, best practice is to follow the code structures from previous assignments and reuse as much code as possible (this makes it easier for us to review it). You can use any libraries, however, we recommend you use: madmom, librosa, pyTorch, etc. (the libraries we have used so far).
#
#
# ### GPU Support
# Our JupyterHub, unfortunately, does not yet provide GPU support. Nevertheless, this assignemnt can be run as-is on JupyterHub, however training of the neural network will take a long time.
#
# In order to speed up training if you are in a hurry, you can run this notebook on any local machine with GPU and cuda support, or alternatively use infrastructure like [Google colab](https://colab.research.google.com/) and drive, if you have a google account.
#
# Simply upload your solved notebook and necessary other files, like output model file, back to JupyterHub for your submission.

# %%
import os
# This code block enables this notebook to run on google colab.
try:
    from google.colab import drive
    print('Running in colab...\n===================')
    COLAB = True
    # !pip install madmom torch==1.4.0 torchvision==0.5.0 librosa --upgrade
    print('Installed dependencies!\n=======================')

    if not os.path.exists('data'):
        print('Downloading data...\n===================')
        # !mkdir data
        # !cd data
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.1.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.2.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.3.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.4.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.5.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.6.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.7.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.8.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.doc.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.error.zip?download=1
        # !wget https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.meta.zip?download=1
            
        # !wget https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.audio.1.zip?download=1
        # !wget https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.audio.2.zip?download=1
        # !wget https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.audio.3.zip?download=1
        # !wget https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.doc.zip?download=1
        # !wget https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.meta.zip?download=1
            
        # !for file in *.*; do mv $file ${file%?download=1}; done
        
        # !unzip "*.zip"
        # !rm *.zip
        # !cd ..

    print('===================\nMake sure you activated GPU support: Edit->Notebook settings->Hardware acceleration->GPU\n==================')
except:
    print('=======================\nNOT running in colab...\n=======================')
    COLAB = False
# Out:
# Running in colab...
# ===================
# Collecting madmom
#   Downloading madmom-0.16.1.tar.gz (20.0 MB)
#      |████████████████████████████████| 20.0 MB 1.2 MB/s
# Collecting torch==1.4.0
#   Downloading torch-1.4.0-cp37-cp37m-manylinux1_x86_64.whl (753.4 MB)
#      |████████████████████████████████| 753.4 MB 7.3 kB/s
# Collecting torchvision==0.5.0
#   Downloading torchvision-0.5.0-cp37-cp37m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 34.8 MB/s
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Collecting librosa
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      |████████████████████████████████| 213 kB 48.0 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0) (1.21.5)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.7/dist-packages (from madmom) (1.4.1)
# Requirement already satisfied: cython>=0.25 in /usr/local/lib/python3.7/dist-packages (from madmom) (0.29.28)
# Collecting mido>=1.2.8
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 5.8 MB/s
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: audioread>=2.1.5 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.3)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->librosa) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->librosa) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (3.0.7)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Building wheels for collected packages: madmom
#   Building wheel for madmom (setup.py) ... done
#   Created wheel for madmom: filename=madmom-0.16.1-cp37-cp37m-linux_x86_64.whl size=20935901 sha256=0e774c4b0958f0f48602b1fc31a0f00bcb461c4f77164a2bc2415fde47df7e72
#   Stored in directory: /root/.cache/pip/wheels/af/90/61/393ceef814b55b12d1b59b5ed3a2b2a3457a55d39b7363b975
# Successfully built madmom
# Installing collected packages: torch, mido, torchvision, madmom, librosa
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# Successfully installed librosa-0.9.1 madmom-0.16.1 mido-1.2.10 torch-1.4.0 torchvision-0.5.0
# Installed dependencies!
# =======================
# Downloading data...
# ===================
# --2022-02-28 17:39:38--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.1.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1070981236 (1021M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.audio.1.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1021M  22.8MB/s    in 44s
#
# 2022-02-28 17:40:25 (23.2 MB/s) - ‘TUT-acoustic-scenes-2016-development.audio.1.zip?download=1’ saved [1070981236/1070981236]
#
# --2022-02-28 17:40:25--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.2.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1067186166 (1018M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.audio.2.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1018M  12.1MB/s    in 2m 12s
#
# 2022-02-28 17:42:39 (7.68 MB/s) - ‘TUT-acoustic-scenes-2016-development.audio.2.zip?download=1’ saved [1067186166/1067186166]
#
# --2022-02-28 17:42:39--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.3.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1073644405 (1024M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.audio.3.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1024M  14.4MB/s    in 55s
#
# 2022-02-28 17:43:36 (18.6 MB/s) - ‘TUT-acoustic-scenes-2016-development.audio.3.zip?download=1’ saved [1073644405/1073644405]
#
# --2022-02-28 17:43:36--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.4.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1072111347 (1022M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.audio.4.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1022M  4.82MB/s    in 1m 48s
#
# 2022-02-28 17:45:26 (9.47 MB/s) - ‘TUT-acoustic-scenes-2016-development.audio.4.zip?download=1’ saved [1072111347/1072111347]
#
# --2022-02-28 17:45:26--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.5.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1069681513 (1020M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.audio.5.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1020M  12.4MB/s    in 81s
#
# 2022-02-28 17:46:48 (12.7 MB/s) - ‘TUT-acoustic-scenes-2016-development.audio.5.zip?download=1’ saved [1069681513/1069681513]
#
# --2022-02-28 17:46:48--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.6.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1072890150 (1023M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.audio.6.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1023M  16.7MB/s    in 54s
#
# 2022-02-28 17:47:44 (18.8 MB/s) - ‘TUT-acoustic-scenes-2016-development.audio.6.zip?download=1’ saved [1072890150/1072890150]
#
# --2022-02-28 17:47:44--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.7.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1069265197 (1020M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.audio.7.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1020M  14.2MB/s    in 63s
#
# 2022-02-28 17:48:49 (16.2 MB/s) - ‘TUT-acoustic-scenes-2016-development.audio.7.zip?download=1’ saved [1069265197/1069265197]
#
# --2022-02-28 17:48:49--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.audio.8.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 528461098 (504M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.audio.8.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>] 503.98M  23.9MB/s    in 22s
#
# 2022-02-28 17:49:12 (22.8 MB/s) - ‘TUT-acoustic-scenes-2016-development.audio.8.zip?download=1’ saved [528461098/528461098]
#
# --2022-02-28 17:49:12--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.doc.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69671 (68K) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.doc.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]  68.04K  --.-KB/s    in 0.1s
#
# 2022-02-28 17:49:14 (587 KB/s) - ‘TUT-acoustic-scenes-2016-development.doc.zip?download=1’ saved [69671/69671]
#
# --2022-02-28 17:49:14--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.error.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1283 (1.3K) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.error.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1.25K  --.-KB/s    in 0s
#
# 2022-02-28 17:49:16 (216 MB/s) - ‘TUT-acoustic-scenes-2016-development.error.zip?download=1’ saved [1283/1283]
#
# --2022-02-28 17:49:16--  https://zenodo.org/record/45739/files/TUT-acoustic-scenes-2016-development.meta.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28815 (28K) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-development.meta.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]  28.14K  --.-KB/s    in 0s
#
# 2022-02-28 17:49:18 (262 MB/s) - ‘TUT-acoustic-scenes-2016-development.meta.zip?download=1’ saved [28815/28815]
#
# --2022-02-28 17:49:18--  https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.audio.1.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1067685684 (1018M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-evaluation.audio.1.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1018M  21.9MB/s    in 44s
#
# 2022-02-28 17:50:04 (23.2 MB/s) - ‘TUT-acoustic-scenes-2016-evaluation.audio.1.zip?download=1’ saved [1067685684/1067685684]
#
# --2022-02-28 17:50:04--  https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.audio.2.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1068308900 (1019M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-evaluation.audio.2.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   1019M  8.69MB/s    in 98s
#
# 2022-02-28 17:51:44 (10.4 MB/s) - ‘TUT-acoustic-scenes-2016-evaluation.audio.2.zip?download=1’ saved [1068308900/1068308900]
#
# --2022-02-28 17:51:44--  https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.audio.3.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 538894804 (514M) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-evaluation.audio.3.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>] 513.93M  11.4MB/s    in 45s
#
# 2022-02-28 17:52:30 (11.5 MB/s) - ‘TUT-acoustic-scenes-2016-evaluation.audio.3.zip?download=1’ saved [538894804/538894804]
#
# --2022-02-28 17:52:30--  https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.doc.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69217 (68K) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-evaluation.doc.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]  67.59K  --.-KB/s    in 0.1s
#
# 2022-02-28 17:52:32 (514 KB/s) - ‘TUT-acoustic-scenes-2016-evaluation.doc.zip?download=1’ saved [69217/69217]
#
# --2022-02-28 17:52:32--  https://zenodo.org/record/165995/files/TUT-acoustic-scenes-2016-evaluation.meta.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5962 (5.8K) [application/octet-stream]
# Saving to: ‘TUT-acoustic-scenes-2016-evaluation.meta.zip?download=1’
#
# TUT-acoustic-scenes 100%[===================>]   5.82K  --.-KB/s    in 0s
#
# 2022-02-28 17:52:34 (389 MB/s) - ‘TUT-acoustic-scenes-2016-evaluation.meta.zip?download=1’ saved [5962/5962]
#
# Archive:  TUT-acoustic-scenes-2016-development.audio.5.zip
#   inflating: TUT-acoustic-scenes-2016-development/audio/b042_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b098_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b106_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a026_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b062_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b041_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a068_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a001_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b044_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b111_133_163.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a099_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a109_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a128_101_131.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b096_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b113_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a071_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b044_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b091_122_152.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a066_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a092_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b072_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a145_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b003_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b095_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a155_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a017_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b115_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a109_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b052_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a129_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b096_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a098_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a003_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a021_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b034_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a051_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b011_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a096_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b088_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a016_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b034_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a038_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b109_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a113_245_275.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b009_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b037_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b006_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b003_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a137_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a129_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a110_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a128_41_71.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b072_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a031_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b071_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a148_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a012_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a107_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b038_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a014_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a107_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a151_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a133_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b035_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b094_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a089_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b073_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a006_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b069_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b080_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b098_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a157_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b078_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a019_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a112_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a023_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a089_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b016_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a039_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a130_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b072_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a144_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b075_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a058_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b015_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a156_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a095_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b003_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b052_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a153_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b038_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b035_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a057_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a074_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a122_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b042_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b007_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b112_173_203.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a059_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b111_43_73.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a020_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a089_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a079_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b088_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b100_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a068_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a059_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b022_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a016_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b107_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b005_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a144_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b006_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b059_165_195.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a009_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a082_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a122_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a023_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b007_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b031_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b021_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b018_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a016_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b021_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b031_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b100_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a075_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a149_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b112_203_233.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a050_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b031_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a129_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a157_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b048_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b087_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a084_62_92.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a006_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b071_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a155_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a098_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b029_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b065_54_84.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a092_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b073_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a005_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a154_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b003_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a151_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a021_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a104_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a122_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a069_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a012_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b115_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a051_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b086_150_180.wav
#
# Archive:  TUT-acoustic-scenes-2016-development.audio.2.zip
#   inflating: TUT-acoustic-scenes-2016-development/audio/a151_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a156_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b054_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a126_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b065_84_114.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b109_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b084_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a084_152_182.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b053_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b072_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b067_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a095_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a057_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a156_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a105_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a005_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a079_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a148_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a145_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a106_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b007_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a076_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a009_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a105_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b048_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b112_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b007_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a075_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b005_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b035_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b115_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a098_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a069_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b045_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b011_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b078_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b029_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a051_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b054_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b048_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b032_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b086_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b054_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b095_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a148_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a094_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a082_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b106_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b030_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a099_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a084_92_122.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b042_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a094_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a068_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b023_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a140_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b099_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b006_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b073_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b068_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a092_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a027_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b035_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b044_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a003_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a153_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b088_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b073_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b056_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b085_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b030_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a023_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b035_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a099_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b059_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a098_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a034_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a054_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a105_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a038_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a144_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b030_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a036_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b111_73_103.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a010_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b038_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a113_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b009_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a157_197_227.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b006_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b034_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a097_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a099_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a128_131_161.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b064_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a155_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a030_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a057_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a097_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a034_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a054_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b041_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b047_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b096_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b078_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a101_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b079_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b009_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b056_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b033_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a089_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a133_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b091_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b019_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b050_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b092_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a130_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b010_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a094_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b032_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a019_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b036_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a096_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b068_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a137_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a140_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a010_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b021_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b022_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a074_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b089_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b106_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a133_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b109_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a116_78_108.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a126_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b054_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a144_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a116_108_138.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b056_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b048_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b098_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b064_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a005_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a069_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a133_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b110_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b059_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b011_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a019_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a131_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a050_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a071_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a019_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a131_0_30.wav
#
# Archive:  TUT-acoustic-scenes-2016-development.audio.3.zip
#   inflating: TUT-acoustic-scenes-2016-development/audio/a112_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a084_182_212.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b061_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b089_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b073_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b116_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b021_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b019_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a039_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a121_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b004_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a089_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a155_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a021_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b079_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b042_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b084_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a014_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b032_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b085_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a155_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a079_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a158_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a092_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a106_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b113_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a137_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a001_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a153_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b082_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b062_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b050_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a001_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b020_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b018_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b033_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b103_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a038_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a075_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a131_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b089_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a120_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b110_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a052_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a043_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b053_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b033_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b098_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a043_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a096_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b113_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b080_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a022_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b019_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b034_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a104_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b098_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b100_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a021_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b107_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b113_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b056_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b023_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a023_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b015_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a027_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b044_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b022_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a156_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b106_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b031_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b086_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b014_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b039_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b042_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b080_261_291.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b103_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a075_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b054_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a126_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b037_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a003_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a031_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a003_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a020_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a154_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a023_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b095_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b025_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a019_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b034_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a089_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b055_137_167.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b015_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b055_107_137.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b056_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a145_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b109_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a145_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b078_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a128_71_101.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b069_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b086_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a096_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b093_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b089_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a113_155_185.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b079_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b041_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b022_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b044_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a027_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a026_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a021_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a154_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a104_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b039_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a030_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b115_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b030_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b041_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a034_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a009_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a076_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a045_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b032_150_180.wav
# ...
#   inflating: TUT-acoustic-scenes-2016-development/audio/b092_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b016_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b036_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a099_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a099_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a068_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a052_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b059_195_225.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b098_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b089_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a059_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b103_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b064_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a121_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b022_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b062_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b032_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a058_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a003_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a026_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b010_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a107_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a092_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a076_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a017_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b050_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b116_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b064_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a144_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a057_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a140_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a026_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b031_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b034_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a158_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a156_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b039_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b023_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b020_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a106_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b111_193_223.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a062_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a062_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b113_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a110_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b018_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a031_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b079_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a144_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a097_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a110_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b003_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a122_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a058_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a110_240_270.wav
#
# Archive:  TUT-acoustic-scenes-2016-development.audio.7.zip
#   inflating: TUT-acoustic-scenes-2016-development/audio/b086_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a122_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a012_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b093_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b045_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b039_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a130_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a145_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b061_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b079_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a016_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a038_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b067_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b115_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a036_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b113_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a057_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b010_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a126_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a069_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b096_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a112_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b068_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a074_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a133_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a154_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b100_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a062_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b018_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a053_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a009_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a151_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b006_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b031_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b097_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b004_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a071_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b018_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a137_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b065_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a098_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b011_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a149_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b004_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b111_163_193.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b116_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a062_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b094_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a060_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a084_212_242.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b039_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a145_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b097_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b041_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a096_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b110_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b087_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b087_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b032_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a158_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a051_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a116_138_168.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a075_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b032_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b059_135_165.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b005_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b075_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a018_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b097_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b079_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b038_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a094_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b025_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b106_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a126_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a019_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a045_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b110_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b060_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b080_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a062_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a019_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a082_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b085_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b039_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a074_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b020_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a052_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b029_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b035_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b053_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a040_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b025_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b109_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b009_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a109_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b084_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b036_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a128_161_191.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a130_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a036_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b097_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a101_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a022_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b085_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a098_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a105_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b095_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a038_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a074_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a026_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b098_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b082_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b016_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b020_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b089_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b056_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a018_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b095_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b062_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a152_180_210.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b069_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a050_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b071_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b010_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a104_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b031_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a010_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a098_270_300.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a074_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a144_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b087_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b080_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a152_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a057_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a040_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a098_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b115_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b087_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a113_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b029_210_240.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a005_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b065_114_144.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b034_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b039_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b096_90_120.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b093_60_90.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a040_0_30.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b097_150_180.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a120_240_270.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b019_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a018_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/b097_30_60.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a053_120_150.wav
#   inflating: TUT-acoustic-scenes-2016-development/audio/a137_210_240.wav
#
# Archive:  TUT-acoustic-scenes-2016-evaluation.doc.zip
#   inflating: TUT-acoustic-scenes-2016-evaluation/README.html
#   inflating: TUT-acoustic-scenes-2016-evaluation/EULA.pdf
#   inflating: TUT-acoustic-scenes-2016-evaluation/README.md
#
# 16 archives were successfully processed.
# ===================
# Make sure you activated GPU support: Edit->Notebook settings->Hardware acceleration->GPU
# ==================

# %% [markdown]
# ## Audio Scene Classification
#
# Your task is to implement a solution to an auditory scene detection challenge, precisely the DCASE 2016 Acoustic Scene Classification task. Details about the challenge are provided on the [task website](http://dcase.community/challenge2016/task-acoustic-scene-classification).
# 1. You are **free in choosing the strategy that you apply** and can also reuse and modify your implementation of previous assignments, e.g., by modifying the architecture to handle clips of 30 seconds length.
# 2. **Follow the given evaluation strategies of the task**, in particular wrt. development and evaluation datasets and cross validation settings.
# 3. Consider **reducing the amount of data** in a reasonable way, if necessary.
# 4. **Compare your results** to the numbers reported on the task website and comment on you main findings.
#
# Remark: The goal is not to outperform the state of the art, but to experiment with a classification task in the general audio domain. Therefore, you can apply your existing solutions from the music domain and reflect upon the capabilities and limitations of your approach.
#
# The overall goal of this assignment is to implement the method in an elegant way and present your implementation in this notebook:
# 1. **Illustrate your chosen architecture** e.g. by printing the individual layers and the shapes of the forward function if you choose a neural network approach (as we have done in previous assignments).
# 2. **Use plots** to showcase features and evaluation results.
# 3. Output your **final performance** and set it into context.
#
# The rough distribution of points is as follows:
# * 10 Points data preprocessing and data handling
# * 10 Points machine learning architecture (e.g. neural network and data loader)
# * 10 Points training method and evaluation
# * 10 Points results and conclusion
# * 10 Points overall presentation throughout the notebook

# %% [markdown]
# # Task 1: Data Processing (10 Points)
#
# If you work on JupyterHub, find the audiofiles in the shared folder as indicated in the cell below.
# Think about **reasonable features** to use and extract them for the audio files.
# The DCASE dataset is already split into **a development and an evaluation** set. The idea is to only use the evaluation set **once** at the very end when you are confident about your trained system.
# Only use the development set to draw your train/valid/test splits from.
# The dataset comes with **predefined splits** for four-fold cross-validation. Feel free to use your own training setup, but read and **follow the guidelines** that come in the documentation of the dataset!
#
# **Note**: Check the readme files in the dataset folder for more details!!

# %%
import os
import numpy as np

# get dataset path
dataset_path = os.path.join(os.environ['HOME'], 'shared', 'data', 'assignment_7')
if os.path.exists('data'):
    dataset_path = '.'

development_path = os.path.join(dataset_path, 'TUT-acoustic-scenes-2016-development')
evaluation_path = os.path.join(dataset_path, 'TUT-acoustic-scenes-2016-evaluation')

development_audio_path = os.path.join(development_path, 'audio')
development_annotation_file = os.path.join(development_path, 'meta.txt')
development_error_file = os.path.join(development_path, 'error.txt')
split_definition_path = os.path.join(development_path, 'evaluation_setup')

evaluation_annotation_file = os.path.join(evaluation_path, 'meta.txt')
evaluation_audio_path = os.path.join(evaluation_path, 'audio')

data_file_clip_info = os.path.join(dataset_path, 'clip_info_final.csv')
data_file_annotations = os.path.join(dataset_path, 'annotations_final.csv')

# collect list of audio files:
development_audio_files = [af for af in os.listdir(development_audio_path) if af.endswith('.wav')]
evaluation_audio_files = [af for af in os.listdir(evaluation_audio_path) if af.endswith('.wav')]

dev_audio_total_count = len(development_audio_files)
eval_audio_total_count = len(evaluation_audio_files)

print(f'Total number of development audio files: {dev_audio_total_count}')
print(f'Total number of evaluation audio files: {eval_audio_total_count}')
# Out:
# Total number of development audio files: 1170
# Total number of evaluation audio files: 390

# %%
print(len(development_audio_files))

print(development_audio_files[0])
# Out:
# 1170
# a059_90_120.wav

# %% [markdown]
# ### 1.1 Implementation

# %%
from librosa.filters import mel
# Put your data handling code here. 
# You can add additional cells below this one for structuring the notebook.
# Feel free to add markdown cells / plots / tests / etc. if it helps your presentation.
import librosa
from pathlib import Path

# YOUR CODE HERE
audio_len = 30
sample_rate = 44100
fft_frame_size = 512
num_mel_bands = 96
hop_size = 256

exp_feat_shape = (96, 1366)

# HERE I HAVE EXTRACTED THE MFCC FEATURES OF EACH AUDIO FILE

def extract_features(file_list, file_path):
    features = []  # list containing features for each audio file
    file_names = []  # audio file names for features (indices should correspond!), cut path and file extension, only leave names
    # iterate over files and extract features...
    # YOUR CODE HERE
    
    for file in file_list:
        try:
          signal_audio, sr  = librosa.load(file_path + file, sr = sample_rate)
          mel_spectrogram = librosa.feature.melspectrogram(y=signal_audio, sr=sample_rate,n_fft = fft_frame_size,
                                                          hop_length = hop_size, n_mels=num_mel_bands)
          print(len(mel_spectrogram))
          mfcc = librosa.feature.mfcc(S=librosa.power_to_db(mel_spectrogram))
          print(len(mfcc))
          features.append(mfcc)
          file_names.append(Path(file).stem)
        except Exception as e: 
          print(e)
          continue
    
    features = np.asarray(features)
    print(features.shape)
    
    return np.asarray(features), np.asarray(file_names)

# %%
dev_features, dev_feat_files = extract_features(development_audio_files, development_audio_path + "/")

eval_features, eval_feat_files = extract_features(evaluation_audio_files, evaluation_audio_path + "/")

# %%
print(len(dev_feat_files))
# Out:
# 1170

# %%
import pandas as pd

# HERE I AM CREATING ANNOTATION LISTS FOR THE AUDIO SAMPLE FILES
# EACH MFCC HAS AN ANNOTATION AT THE SAME INDEX AFTER THIS

annotations_development = pd.read_csv(development_annotation_file, sep="\t", header=None)
annotations_evaluation = pd.read_csv(evaluation_annotation_file, sep="\t", header=None)

dev_annot = {}
eval_annot = {}

for i, annot in enumerate(annotations_development[0]):
  dev_annot[annot] = annotations_development[1][i]

for i, annot in enumerate(annotations_evaluation[0]):
  eval_annot[annot] = annotations_evaluation[1][i]  


targets_dev = []
targets_eval = []

for audio_file in development_audio_files:
  targets_dev.append(dev_annot["audio/" + audio_file])

for audio_file in evaluation_audio_files:
  targets_eval.append(eval_annot["audio/" + audio_file])


print(len(targets_dev))
print(len(targets_eval))
# Out:
# 1170
# 390
# 1170
# city_center
# 1170
# 390

# %% [markdown]
# ### 1.2 Discussion
#
# Write down what choices you made regarding data structuring and feature extraction, feel free to refer to code/plots/etc. in cells above.

# %% [markdown]
# For the data extraction i have calculated the Mel-Frequency-Capstrol-Coefficients (librosa.feature.mfcc) of the 30 second clips provided.
#
# After that I have created a list of targets that provides the correct classification of each clip.
#
# I will further use the MFCC features to try to classify the clips with a Support Vector Machine and a KNN classifier, to create a classical
# Machine Learning (feature based) approach.

# %% [markdown]
# ## Task 2: Machine Learning Approach (10 Points)
#
# Implement your audio scene classification method here. You are free to use any approach you find appropriate. As a hint: the easiest way to succeed is to adapt the neural network approach from assignment 6 (or 5), since convolutional neural networks have been shown to work very well for this task, and you can start with a running code base.
#
# ### 2.1 Implementation

# %%
# Implement your machine learning architecture in the cells below. 
# You can add additional cells below this one for structuring the notebook.
# Feel free to add markdown cells / plots / tests / etc. if it helps your presentation.

# YOUR CODE HERE

# SVM CLASSIFIER APPROACH
# SUPPORT VECTOR MACHINE (SEPARATOR) - CHAINED FOR THE MULTI CLASS PROBLEM

from sklearn import svm
import pickle

###############################################################
# TRAINING THE SVM
feature_vector_train = dev_features


nsamples, nx, ny = feature_vector_train.shape
d2_train_dataset = feature_vector_train.reshape((nsamples,nx*ny))

# TARGETS
y_train = targets_dev


# CREATE THE  MULTI-CLASS SVM
# ONE-VS-ONE implementation
clf = svm.SVC(decision_function_shape='ovo')
# Out:
# cnn_tagger_0.model  finalized_model_knn.sav  name_cache.npy
# feat_cache.npy	    finalized_model.sav
# (1170, 20, 5168)

# %%
# Out:
# (1170, 20, 5168)
# 0.3717948717948718

# %%
####################################

#  KNN CLASSICIER APPROACH
# k-Nearest-Neighbours (Hedging classifier)

from sklearn.neighbors import KNeighborsClassifier


feature_vector_train = dev_features


nsamples, nx, ny = feature_vector_train.shape
d2_train_dataset = feature_vector_train.reshape((nsamples,nx*ny))

# TARGETS
y_train = targets_dev

neigh = KNeighborsClassifier(n_neighbors = 15)

# %%
# Out:
# 185
# 205
# 0.47435897435897434

# %% [markdown]
# ### 2.2 Discussion
# Write down your choices and findings. Feel free to refer to code/plots/etc. in cells above.
#
# Here I have created 2 classifiers. A simple KNN classifier, and a SVM Classifier. The Support Vector machine is a separator and is commonly a binary classifier. This is why we use the scikit "ovo" implementation of the classifier to link multiple SVM-s to classify for the 15 classes we have in our problem.
# I am expecting these classifiers to perform worse than the Neural Network approach, but I am hoping they won't be much worse.

# %% [markdown]
# ## Task 3: Training, Inference, and Evaluation (10 Points)
#
# Depending on your choices for the machine learning model, implement the appropriate code to train and test it.
# For developing and training the model only use the development set.
#
# ### 3.1 Implementation

# %%
# Put your trainin and evaluation code in the cells below.
# You can add additional cells below this one for structuring the notebook.
# Feel free to add markdown cells / plots / tests / etc. if it helps your presentation.

# YOUR CODE HERE

# %%
# TRAINING THE SVM CLASSIFIER
clf.fit(d2_train_dataset, y_train)

# SAVE THE MODEL
# !ls "/content/drive/MyDrive/audio/"

mod_path = "/content/drive/MyDrive/audio/"

filename = 'finalized_model.sav'

pickle.dump(clf, open(mod_path + filename, 'wb'))

# %%
# EVALUATING THE SUPPORT VECTOR MACHINE
from sklearn.metrics import precision_score

# Calculate Precision, Recall and F-measure
# SVM EVALUATION

filename = "/content/drive/MyDrive/audio/finalized_model.sav"

clf_loaded_model = pickle.load(open(filename, 'rb'))

###############################################################
# TESTING THE SVM
feature_vector_test = eval_features
nsamples, nx, ny = feature_vector_test.shape
d2_test_dataset = feature_vector_test.reshape((nsamples,nx*ny))

# TARGETS
y_test = targets_eval

print(feature_vector_train.shape)


#TEST
outputs_svm = clf_loaded_model.predict(d2_test_dataset)

prec = precision_score(outputs_svm, y_test, average='micro')

print(prec)
# Out:
# (1170, 20, 5168)
# 0.3717948717948718

# %%
# TRAINING THE KNN CLASSIFIER
neigh.fit(d2_train_dataset, y_train)

# SAVE THE MODEL
# !ls "/content/drive/MyDrive/audio/"

mod_path = "/content/drive/MyDrive/audio/"

filename = 'finalized_model_knn.sav'

pickle.dump(neigh, open(mod_path + filename, 'wb'))
# Out:
# cnn_tagger_0.model  finalized_model_knn.sav  name_cache.npy
# feat_cache.npy	    finalized_model.sav

# %%
# EVALUATING THE KNN CLASSIFIER
# Calculate Precision, Recall and F-measure
# KNN Evaluation

filename = "/content/drive/MyDrive/audio/finalized_model_knn.sav"
clf_loaded_model = pickle.load(open(filename, 'rb'))


loaded_model_neigh = pickle.load(open(filename, 'rb'))

###############################################################
# TESTING THE KNN
feature_vector_test = eval_features
nsamples, nx, ny = feature_vector_test.shape
d2_test_dataset = feature_vector_test.reshape((nsamples,nx*ny))

# TARGETS
y_test = targets_eval

#print(feature_vector_train.shape)


#TEST
outputs_knn = loaded_model_neigh.predict(d2_test_dataset)

prec = precision_score(outputs_knn, y_test, average='micro')

print(prec)
# Out:
# 0.4717948717948718

# %% [markdown]
# ### 3.2 Discussion
# Write down your choices and findings. Feel free to refer to code/plots/etc. in cells above.

# %% [markdown]
# Here I have created and Traines the clssifiers. The SVM training took some time, about 10-15 mintues. After that I have calculated the precision of eeach classifier.
# The results are defeating, to say the least.
# Classical classifiers obviosly perform severly worse than a Neural Network Approach for the problem of Audio scene Classification.
#
# SVM precision: 37%
#
# KNN precision: 47%

# %% [markdown]
# ## Task 4: Results and Conclusion (10 Points)
#
# Use the code cells below to calculate the final performance of the developed approach on the evaluation part of the dataset.

# %%
# Put the evaluation code on the evaulation dataset in these code cells.
# You can add additional cells below this one for structuring the notebook.
# Feel free to add markdown cells / plots / tests / etc. if it helps your presentation.

# YOUR CODE HERE
from sklearn.metrics import f1_score

# SVM F1 SCORE

values_numbers = {}

cnt = 0
for val in y_test:
  if val not in values_numbers:
    values_numbers[val] = cnt
    cnt += 1


y_true = []
y_pred = []

for out in outputs_svm:
  y_pred.append(values_numbers[out])

for an in y_test:
  y_true.append(values_numbers[an])


# F1 SCORE
f1_macro = f1_score(y_true, y_pred, average='macro')

f1_micro = f1_score(y_true, y_pred, average='micro')

f1_weigh = f1_score(y_true, y_pred, average='weighted')

print("SVM F1 MACRO: " + str(f1_macro) + " SVM F1 MACRO: " + str(f1_macro) + " SVM F1 WEIGH: " + str(f1_weigh))
# Out:
# SVM F1 MACRO: 0.3241436442734849 SVM F1 MACRO: 0.3241436442734849 SVM F1 WEIGH: 0.3241436442734849

# %%
# KNN F1 SCORE

values_numbers = {}

cnt = 0
for val in y_test:
  if val not in values_numbers:
    values_numbers[val] = cnt
    cnt += 1


y_true = []
y_pred = []

for out in outputs_knn:
  y_pred.append(values_numbers[out])

for an in y_test:
  y_true.append(values_numbers[an])




# F1 SCORE
f1_macro = f1_score(y_true, y_pred, average='macro')

f1_micro = f1_score(y_true, y_pred, average='micro')

f1_weigh = f1_score(y_true, y_pred, average='weighted')

print("SVM F1 MACRO: " + str(f1_macro) + " SVM F1 MACRO: " + str(f1_macro) + " SVM F1 WEIGH: " + str(f1_weigh))
# Out:
# SVM F1 MACRO: 0.4203283396604311 SVM F1 MACRO: 0.4203283396604311 SVM F1 WEIGH: 0.4203283396604312

# %% [markdown]
# ### Task 4.2 Discussion
#
# Compare your performance to the ones shown on the DCASE website, and discuss possible reasons for performance differences.
# Discuss your approach in the context of the other methods presented on the DCASE website.

# %% [markdown]
# We can see by the precision and F1-scores we are getting (0.32 for the SVM, and 0.42 for the KNN) classiciers that my method with the MFCC features and the classical ML approach severly underperforms compared even to the lowes displayed classifier on the Challenge Website (62%).
#
# Conclusion: I have confirmed my suspicion that the Neural Network approaches work better for audio classification, because they integrate the most important part of audio processing - the switch to the frequency domain by utilizing spectrograms, and then work out better features than the MFCC.

# %% [markdown]
# ## Task 5: Overall Presentation (10 Points)
#
# Make sure your notebook **clearly presents your chosen approach** to the problem solution. If necessary, revisit the individual tasks and **add plots, outputs, code comments**, etc. to clearly explain what is going on.
#
# You do not need to overdo it (no endless prints or plots that bloat the notebook) - less is sometimes more - as a goal think about your peers in the lecture and make it so that they could easily understand what is going on in the notebook. Exemplary plots with overall metrics are usually a nice compromise.

# %% [markdown]
# ## Congratulations, you are done!
#
# Reminder:
# Before you turn this assignment in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
