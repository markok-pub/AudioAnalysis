# %% [markdown]
# Before you turn this assignment in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says "YOUR ANSWER HERE" or `YOUR CODE HERE` and remove the `raise NotImplementedError()` lines.
#
# Code blocks starting with a `# tests` comment provide unit tests which have to run without errors in order to get full points. Be aware that there might be further 'secret' tests to check correct implementation! I.e. the provided unit tests are necessary but not sufficient for full points!
#
# You are always welcome to add **additional plots, tests, or debug outputs**.
# However, make sure to: **1) not break the automated tests**, and **2) switch off any excessive debug output** when you submit your notebook!
#
# Please add your name and student ID below:

# %%
NAME = "Marko Kadic"
STUDENT_ID = "12045128"

import librosa
M
import pandas as pd
from random import randrange

# %%
assert len(NAME) > 0, "Enter your name!"
assert len(STUDENT_ID) > 0, "Enter your student ID!"

# %% [markdown]
# # Intelligent Audio and Music Analysis Assignment 6
#
# This assignment accounts for 50 points of the 3rd and last assignment block (100 points total)
#
# Assignment 6 and 7 are more free form than the previous assignments. The goal is to apply what has been practiced so far. For implementing assignments 6 and 7, follow the code structures from previous assignments and reuse as much code as possible. You can use any libraries, we recommend madmom, librosa, pyTorch, etc. (the libraries we have used so far).
#
# ## Semantic Music Tagging
#
# Following the approach by [Choi et al. \[2016\]](https://arxiv.org/pdf/1606.00298.pdf) “Automatic Tagging Using Deep Convolutional Neural Networks”, a CNN architecture shall be implemented to predict semantic categories for short clips of music pieces. As suggested, for experiments, the MagnaTagATune dataset will be used.
#
#
#
# ### GPU Support
# Our JupyterHub, unfortunately, does not yet provide GPU support. Nevertheless, this assignment can be run as-is on JupyterHub, however training of the neural network will take even longer than last time.
#
# In order to speed up training if you are in a hurry, you can run this notebook on any local machine with GPU and cuda support, or alternatively use infrastructure like [google colab](https://colab.research.google.com/) and drive, if you have a google account.
#
# Simply upload your solved notebook and output model file back to JupyterHub for your submission.

# %%
import os
# This code block enables this notebook to run on google colab.
try:
    from google.colab import drive
    print('Running in colab...\n===================')
    COLAB = True
    # !pip install madmom librosa torch==1.4.0 torchvision==0.5.0 --upgrade
    print('Installed dependencies!\n=======================')

    if not os.path.exists('audio'):
        print('Downloading data...\n===================')
        # !wget http://mi.soi.city.ac.uk/datasets/magnatagatune/clip_info_final.csv
        # !wget http://mi.soi.city.ac.uk/datasets/magnatagatune/annotations_final.csv
        # !wget http://mi.soi.city.ac.uk/datasets/magnatagatune/mp3.zip.001
        # !wget http://mi.soi.city.ac.uk/datasets/magnatagatune/mp3.zip.002
        # !wget http://mi.soi.city.ac.uk/datasets/magnatagatune/mp3.zip.003
        # !cat mp3.zip.* > mp3.zip
        # !mkdir audio
        # !unzip mp3.zip -d audio
        # !rm mp3.zip.*
        
        # optionally download cached features
        # !mkdir cache
        # !wget -O cache/feat_cache.npy "http://www.ifs.tuwien.ac.at/~vogl/other/feat_cache.npy"
        # !wget -O cache/name_cache.npy "http://www.ifs.tuwien.ac.at/~vogl/other/name_cache.npy"

    print('===================\nMake sure you activated GPU support: Edit->Notebook settings->Hardware acceleration->GPU\n==================')
except:
    print('=======================\nNOT running in colab...\n=======================')
    COLAB = False
# Out:
# Running in colab...
# ===================
# Collecting madmom
#   Downloading madmom-0.16.1.tar.gz (20.0 MB)
#      |████████████████████████████████| 20.0 MB 1.4 MB/s
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Collecting librosa
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      |████████████████████████████████| 213 kB 41.5 MB/s
# Collecting torch==1.4.0
#   Downloading torch-1.4.0-cp37-cp37m-manylinux1_x86_64.whl (753.4 MB)
#      |████████████████████████████████| 753.4 MB 7.1 kB/s
# Collecting torchvision==0.5.0
#   Downloading torchvision-0.5.0-cp37-cp37m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 34.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0) (1.21.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0) (1.15.0)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.7/dist-packages (from madmom) (1.4.1)
# Requirement already satisfied: cython>=0.25 in /usr/local/lib/python3.7/dist-packages (from madmom) (0.29.28)
# Collecting mido>=1.2.8
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 6.8 MB/s
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: audioread>=2.1.5 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.3)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->librosa) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->librosa) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (3.0.7)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Building wheels for collected packages: madmom
#   Building wheel for madmom (setup.py) ... done
#   Created wheel for madmom: filename=madmom-0.16.1-cp37-cp37m-linux_x86_64.whl size=20935919 sha256=3352d176be662d9ed127c5d964feedaaa81afcf804ca4f9aacbe6b7d93fbe4d9
#   Stored in directory: /root/.cache/pip/wheels/af/90/61/393ceef814b55b12d1b59b5ed3a2b2a3457a55d39b7363b975
# Successfully built madmom
# Installing collected packages: torch, mido, torchvision, madmom, librosa
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# Successfully installed librosa-0.9.1 madmom-0.16.1 mido-1.2.10 torch-1.4.0 torchvision-0.5.0
# Streaming output truncated to the last 5000 lines.
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-19-ouverture_burlesque_menuet_telemann-117-146.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-19-ouverture_burlesque_menuet_telemann-30-59.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-19-ouverture_burlesque_menuet_telemann-59-88.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-20-ouverture_burlesque_giga_telemann-88-117.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-21-ouverture_burlesque_marche_pour_monsieur_le_capitaine_weber_telemann-0-29.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-21-ouverture_burlesque_marche_pour_monsieur_le_capitaine_weber_telemann-30-59.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-21-ouverture_burlesque_marche_pour_monsieur_le_capitaine_weber_telemann-59-88.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-22-ouverture_burlesque_retraite_allegro_telemann-0-29.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-24-suite_allemande_vivement_pezold-117-146.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-25-suite_courante_pezold-0-29.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-25-suite_courante_pezold-146-175.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-25-suite_courante_pezold-175-204.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-25-suite_courante_pezold-30-59.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-25-suite_courante_pezold-59-88.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-26-suite_sarabande_pezold-175-204.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-26-suite_sarabande_pezold-30-59.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-26-suite_sarabande_pezold-59-88.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-26-suite_sarabande_pezold-88-117.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-27-suite_gigue_pezold-0-29.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-27-suite_gigue_pezold-117-146.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-27-suite_gigue_pezold-146-175.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-27-suite_gigue_pezold-30-59.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-27-suite_gigue_pezold-59-88.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-28-suite_menuet_en_rondau_pezold-117-146.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-28-suite_menuet_en_rondau_pezold-233-262.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-28-suite_menuet_en_rondau_pezold-30-59.mp3
#   inflating: audio/d/janine_johnson-telemann_harpsichord_solos_from_der_getreue_music_meister-28-suite_menuet_en_rondau_pezold-59-88.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-01-mockingbird-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-01-mockingbird-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-02-guinevere-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-02-guinevere-117-146.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-03-mist-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-04-green_turtleneck-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-06-she_misses_the_ocean-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-06-she_misses_the_ocean-88-117.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-07-india-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-07-india-88-117.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-08-oh_yeah-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-09-spanish_ballad-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-09-spanish_ballad-59-88.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-09-spanish_ballad-88-117.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-10-groove-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-10-groove-59-88.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-10-groove-88-117.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-11-waterfall-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-12-horsetooth_soliloquoy-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-12-horsetooth_soliloquoy-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-12-horsetooth_soliloquoy-59-88.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-13-discovery-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-13-discovery-88-117.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-14-allegro_in_d_minor-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-14-allegro_in_d_minor-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-14-allegro_in_d_minor-88-117.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-15-run-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-15-run-59-88.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-17-victory-59-88.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-17-victory-88-117.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-19-train-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-19-train-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-19-train-59-88.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-20-night-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-20-night-30-59.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-20-night-59-88.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-21-get_it_right-0-29.mp3
#   inflating: audio/d/jeff_wahl-guitarscapes-22-butterfly-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-01-suite_no_4_in_e_flat_major_bwv_815_allemande-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-01-suite_no_4_in_e_flat_major_bwv_815_allemande-175-204.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-01-suite_no_4_in_e_flat_major_bwv_815_allemande-204-233.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-01-suite_no_4_in_e_flat_major_bwv_815_allemande-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-01-suite_no_4_in_e_flat_major_bwv_815_allemande-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-02-suite_no_4_in_e_flat_major_bwv_815_courante-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-03-suite_no_4_in_e_flat_major_bwv_815_sarabande-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-03-suite_no_4_in_e_flat_major_bwv_815_sarabande-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-03-suite_no_4_in_e_flat_major_bwv_815_sarabande-146-175.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-03-suite_no_4_in_e_flat_major_bwv_815_sarabande-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-03-suite_no_4_in_e_flat_major_bwv_815_sarabande-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-03-suite_no_4_in_e_flat_major_bwv_815_sarabande-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-04-suite_no_4_in_e_flat_major_bwv_815_gavotte-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-05-suite_no_4_in_e_flat_major_bwv_815_menuet-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-06-suite_no_4_in_e_flat_major_bwv_815_air-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-07-suite_no_4_in_e_flat_major_bwv_815_gigue-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-07-suite_no_4_in_e_flat_major_bwv_815_gigue-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-07-suite_no_4_in_e_flat_major_bwv_815_gigue-146-175.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-07-suite_no_4_in_e_flat_major_bwv_815_gigue-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-07-suite_no_4_in_e_flat_major_bwv_815_gigue-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-08-suite_no_2_in_c_minor_bwv_813_allemande-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-08-suite_no_2_in_c_minor_bwv_813_allemande-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-08-suite_no_2_in_c_minor_bwv_813_allemande-175-204.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-08-suite_no_2_in_c_minor_bwv_813_allemande-204-233.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-08-suite_no_2_in_c_minor_bwv_813_allemande-233-262.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-08-suite_no_2_in_c_minor_bwv_813_allemande-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-08-suite_no_2_in_c_minor_bwv_813_allemande-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-09-suite_no_2_in_c_minor_bwv_813_courante-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-09-suite_no_2_in_c_minor_bwv_813_courante-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-10-suite_no_2_in_c_minor_bwv_813_sarabande-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-10-suite_no_2_in_c_minor_bwv_813_sarabande-175-204.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-10-suite_no_2_in_c_minor_bwv_813_sarabande-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-11-suite_no_2_in_c_minor_bwv_813_air-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-12-suite_no_2_in_c_minor_bwv_813_menuet-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-12-suite_no_2_in_c_minor_bwv_813_menuet-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-13-suite_no_2_in_c_minor_bwv_813_gigue-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-13-suite_no_2_in_c_minor_bwv_813_gigue-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-13-suite_no_2_in_c_minor_bwv_813_gigue-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-13-suite_no_2_in_c_minor_bwv_813_gigue-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-14-suite_no_3_in_b_minor_bwv_814_allemande-146-175.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-14-suite_no_3_in_b_minor_bwv_814_allemande-175-204.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-14-suite_no_3_in_b_minor_bwv_814_allemande-204-233.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-14-suite_no_3_in_b_minor_bwv_814_allemande-233-262.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-14-suite_no_3_in_b_minor_bwv_814_allemande-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-14-suite_no_3_in_b_minor_bwv_814_allemande-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-15-suite_no_3_in_b_minor_bwv_814_courante-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-15-suite_no_3_in_b_minor_bwv_814_courante-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-15-suite_no_3_in_b_minor_bwv_814_courante-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-15-suite_no_3_in_b_minor_bwv_814_courante-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-16-suite_no_3_in_b_minor_bwv_814_sarabande-146-175.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-16-suite_no_3_in_b_minor_bwv_814_sarabande-204-233.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-16-suite_no_3_in_b_minor_bwv_814_sarabande-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-16-suite_no_3_in_b_minor_bwv_814_sarabande-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-16-suite_no_3_in_b_minor_bwv_814_sarabande-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-17-suite_no_3_in_b_minor_bwv_814_anglaise-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-17-suite_no_3_in_b_minor_bwv_814_anglaise-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-18-suite_no_3_in_b_minor_bwv_814_menuet_and_trio-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-18-suite_no_3_in_b_minor_bwv_814_menuet_and_trio-146-175.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-19-suite_no_3_in_b_minor_bwv_814_gigue-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-19-suite_no_3_in_b_minor_bwv_814_gigue-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-20-suite_no_5_in_g_major_bwv_816_allemande-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-20-suite_no_5_in_g_major_bwv_816_allemande-175-204.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-20-suite_no_5_in_g_major_bwv_816_allemande-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-20-suite_no_5_in_g_major_bwv_816_allemande-88-117.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-21-suite_no_5_in_g_major_bwv_816_courante-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-22-suite_no_5_in_g_major_bwv_816_sarabande-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-22-suite_no_5_in_g_major_bwv_816_sarabande-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-22-suite_no_5_in_g_major_bwv_816_sarabande-175-204.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-22-suite_no_5_in_g_major_bwv_816_sarabande-204-233.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-22-suite_no_5_in_g_major_bwv_816_sarabande-233-262.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-22-suite_no_5_in_g_major_bwv_816_sarabande-262-291.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-22-suite_no_5_in_g_major_bwv_816_sarabande-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-22-suite_no_5_in_g_major_bwv_816_sarabande-320-349.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-22-suite_no_5_in_g_major_bwv_816_sarabande-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-23-suite_no_5_in_g_major_bwv_816_gavotte-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-23-suite_no_5_in_g_major_bwv_816_gavotte-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-24-suite_no_5_in_g_major_bwv_816_bourree-30-59.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-24-suite_no_5_in_g_major_bwv_816_bourree-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-25-suite_no_5_in_g_major_bwv_816_loure-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-25-suite_no_5_in_g_major_bwv_816_loure-146-175.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-25-suite_no_5_in_g_major_bwv_816_loure-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-26-suite_no_5_in_g_major_bwv_816_gigue-0-29.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-26-suite_no_5_in_g_major_bwv_816_gigue-117-146.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-26-suite_no_5_in_g_major_bwv_816_gigue-146-175.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-26-suite_no_5_in_g_major_bwv_816_gigue-175-204.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-26-suite_no_5_in_g_major_bwv_816_gigue-59-88.mp3
#   inflating: audio/d/katherine_roberts_perl-j_s__bach_french_suites-26-suite_no_5_in_g_major_bwv_816_gigue-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-01-tec_peleite_zernju_zogtu_latvia-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-01-tec_peleite_zernju_zogtu_latvia-117-146.mp3
#   inflating: audio/d/kitka-wintersongs-01-tec_peleite_zernju_zogtu_latvia-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-01-tec_peleite_zernju_zogtu_latvia-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-02-byla_cesta_moravia-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-02-byla_cesta_moravia-146-175.mp3
#   inflating: audio/d/kitka-wintersongs-02-byla_cesta_moravia-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-03-domnulet_si_domn_din_cer_romania-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-03-domnulet_si_domn_din_cer_romania-175-204.mp3
#   inflating: audio/d/kitka-wintersongs-03-domnulet_si_domn_din_cer_romania-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-04-zamuchi_se_bozha_majka_bulgaria-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-04-zamuchi_se_bozha_majka_bulgaria-117-146.mp3
#   inflating: audio/d/kitka-wintersongs-05-alilo_georgia-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-05-alilo_georgia-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-05-alilo_georgia-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-05-alilo_georgia-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-06-otche_nash_russia_bulgaria-117-146.mp3
#   inflating: audio/d/kitka-wintersongs-06-otche_nash_russia_bulgaria-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-06-otche_nash_russia_bulgaria-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-07-sculati_gazde_nu_dormiti_romania-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-07-sculati_gazde_nu_dormiti_romania-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-08-betlehem_betlehem_hungary-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-08-betlehem_betlehem_hungary-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-09-dontojno_jest_bulgaria-146-175.mp3
#   inflating: audio/d/kitka-wintersongs-09-dontojno_jest_bulgaria-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-09-dontojno_jest_bulgaria-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-09-dontojno_jest_bulgaria-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-10-oj_jak_priletaly_taj_dva_sokolonky_ukraine-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-10-oj_jak_priletaly_taj_dva_sokolonky_ukraine-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-10-oj_jak_priletaly_taj_dva_sokolonky_ukraine-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-10-oj_jak_priletaly_taj_dva_sokolonky_ukraine-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-11-oj_u_horodi_ukraine-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-11-oj_u_horodi_ukraine-146-175.mp3
#   inflating: audio/d/kitka-wintersongs-11-oj_u_horodi_ukraine-175-204.mp3
#   inflating: audio/d/kitka-wintersongs-11-oj_u_horodi_ukraine-204-233.mp3
#   inflating: audio/d/kitka-wintersongs-11-oj_u_horodi_ukraine-233-262.mp3
#   inflating: audio/d/kitka-wintersongs-11-oj_u_horodi_ukraine-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-11-oj_u_horodi_ukraine-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-12-bozha_zvezda_bulgarian_macedonia-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-12-bozha_zvezda_bulgarian_macedonia-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-12-bozha_zvezda_bulgarian_macedonia-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-13-ayios_vasilis_greece-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-13-ayios_vasilis_greece-117-146.mp3
#   inflating: audio/d/kitka-wintersongs-13-ayios_vasilis_greece-146-175.mp3
#   inflating: audio/d/kitka-wintersongs-13-ayios_vasilis_greece-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-13-ayios_vasilis_greece-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-13-ayios_vasilis_greece-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-14-tsarsko_momche_kon_sedlae_bulgaria-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-14-tsarsko_momche_kon_sedlae_bulgaria-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-14-tsarsko_momche_kon_sedlae_bulgaria-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-15-ma_navu_israel-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-15-ma_navu_israel-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-15-ma_navu_israel-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-15-ma_navu_israel-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-16-shen_khar_venakhi_georgia-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-16-shen_khar_venakhi_georgia-146-175.mp3
#   inflating: audio/d/kitka-wintersongs-16-shen_khar_venakhi_georgia-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-16-shen_khar_venakhi_georgia-88-117.mp3
#   inflating: audio/d/kitka-wintersongs-17-shchedrik_ukraine-59-88.mp3
#   inflating: audio/d/kitka-wintersongs-18-a_v_jerusalime_south_russia_ukraine-0-29.mp3
#   inflating: audio/d/kitka-wintersongs-18-a_v_jerusalime_south_russia_ukraine-117-146.mp3
#   inflating: audio/d/kitka-wintersongs-18-a_v_jerusalime_south_russia_ukraine-30-59.mp3
#   inflating: audio/d/kitka-wintersongs-18-a_v_jerusalime_south_russia_ukraine-59-88.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-01-rachmaninovpraise_the_lord_from_the_heavens-0-29.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-01-rachmaninovpraise_the_lord_from_the_heavens-146-175.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-01-rachmaninovpraise_the_lord_from_the_heavens-30-59.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-02-rachmaninovbless_the_lord_o_my_soul-117-146.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-02-rachmaninovbless_the_lord_o_my_soul-146-175.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-02-rachmaninovbless_the_lord_o_my_soul-204-233.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-02-rachmaninovbless_the_lord_o_my_soul-233-262.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-02-rachmaninovbless_the_lord_o_my_soul-59-88.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-03-rachmaninovto_thee_we_sing-0-29.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-03-rachmaninovto_thee_we_sing-175-204.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-03-rachmaninovto_thee_we_sing-30-59.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-03-rachmaninovto_thee_we_sing-59-88.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-03-rachmaninovto_thee_we_sing-88-117.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-04-rachmaninofo_theotokos_and_virgin_rejoice-30-59.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-04-rachmaninofo_theotokos_and_virgin_rejoice-88-117.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-05-shvedovto_thee_we_sing-0-29.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-05-shvedovto_thee_we_sing-30-59.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-05-shvedovto_thee_we_sing-88-117.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-06-chesnokovdo_not_forsake_me-175-204.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-06-chesnokovdo_not_forsake_me-204-233.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-06-chesnokovdo_not_forsake_me-233-262.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-06-chesnokovdo_not_forsake_me-262-291.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-06-chesnokovdo_not_forsake_me-59-88.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-06-chesnokovdo_not_forsake_me-88-117.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-07-chesnokovlets_please_joseph-117-146.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-07-chesnokovlets_please_joseph-175-204.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-08-chesnokovto_the_holy_virgin_we_pray-146-175.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-08-chesnokovto_the_holy_virgin_we_pray-175-204.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-09-grechaninovthe_litany_of_fervent_supplication-117-146.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-09-grechaninovthe_litany_of_fervent_supplication-146-175.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-09-grechaninovthe_litany_of_fervent_supplication-233-262.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-09-grechaninovthe_litany_of_fervent_supplication-291-320.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-09-grechaninovthe_litany_of_fervent_supplication-30-59.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-09-grechaninovthe_litany_of_fervent_supplication-59-88.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-09-grechaninovthe_litany_of_fervent_supplication-88-117.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-10-grechaninovthe_cherubic_hymn-146-175.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-10-grechaninovthe_cherubic_hymn-175-204.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-10-grechaninovthe_cherubic_hymn-204-233.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-10-grechaninovthe_cherubic_hymn-30-59.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-10-grechaninovthe_cherubic_hymn-59-88.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-11-grechaninovto_the_holy_virgin_mary-175-204.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-11-grechaninovto_the_holy_virgin_mary-204-233.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-11-grechaninovto_the_holy_virgin_mary-349-378.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-11-grechaninovto_the_holy_virgin_mary-88-117.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-12-balakirevfrom_above_the_prophets-0-29.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-12-balakirevfrom_above_the_prophets-146-175.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-12-balakirevfrom_above_the_prophets-175-204.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-12-balakirevfrom_above_the_prophets-30-59.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-12-balakirevfrom_above_the_prophets-59-88.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-12-balakirevfrom_above_the_prophets-88-117.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-13-archangelskyi_think_upon_the_faithful_day-0-29.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-13-archangelskyi_think_upon_the_faithful_day-146-175.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-13-archangelskyi_think_upon_the_faithful_day-233-262.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-13-archangelskyi_think_upon_the_faithful_day-349-378.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-14-archangelskythe_symbol_of_the_faith-0-29.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-14-archangelskythe_symbol_of_the_faith-117-146.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-14-archangelskythe_symbol_of_the_faith-146-175.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-14-archangelskythe_symbol_of_the_faith-30-59.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-15-lvovof_thy_mystical_supper-0-29.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-15-lvovof_thy_mystical_supper-117-146.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-15-lvovof_thy_mystical_supper-146-175.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-15-lvovof_thy_mystical_supper-175-204.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-15-lvovof_thy_mystical_supper-59-88.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-15-lvovof_thy_mystical_supper-88-117.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-16-tchaikovskyo_holy_god-0-29.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-16-tchaikovskyo_holy_god-30-59.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-17-tchaikovskypraise_the_lord_from_the_heavens-204-233.mp3
#   inflating: audio/d/kyiv_chamber_choir-praise_the_lord-17-tchaikovskypraise_the_lord_from_the_heavens-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-01-ehren_starks_the_tale_of_room_620-117-146.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-01-ehren_starks_the_tale_of_room_620-146-175.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-01-ehren_starks_the_tale_of_room_620-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-01-ehren_starks_the_tale_of_room_620-262-291.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-117-146.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-146-175.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-233-262.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-262-291.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-291-320.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-320-349.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-465-494.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-494-523.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-02-beth_quist_q_song-59-88.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-03-paul_berget_recercar_2-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-03-paul_berget_recercar_2-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-04-stellamara_immrama-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-04-stellamara_immrama-146-175.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-04-stellamara_immrama-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-04-stellamara_immrama-233-262.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-04-stellamara_immrama-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-05-jan_hanford_prelude_no__14_in_d_minor-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-05-jan_hanford_prelude_no__14_in_d_minor-59-88.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-06-hans_christian_backwards_with_my_eyes_closed-146-175.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-06-hans_christian_backwards_with_my_eyes_closed-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-06-hans_christian_backwards_with_my_eyes_closed-204-233.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-06-hans_christian_backwards_with_my_eyes_closed-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-06-hans_christian_backwards_with_my_eyes_closed-59-88.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-07-dac_crowell_northeastern_corridor-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-07-dac_crowell_northeastern_corridor-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-07-dac_crowell_northeastern_corridor-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-07-dac_crowell_northeastern_corridor-59-88.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-08-kourosh_zolani_goodbye_homeland-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-08-kourosh_zolani_goodbye_homeland-117-146.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-08-kourosh_zolani_goodbye_homeland-146-175.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-08-kourosh_zolani_goodbye_homeland-291-320.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-08-kourosh_zolani_goodbye_homeland-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-08-kourosh_zolani_goodbye_homeland-88-117.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-09-bjorn_fogelberg_karooshi_porn-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-09-bjorn_fogelberg_karooshi_porn-146-175.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-09-bjorn_fogelberg_karooshi_porn-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-09-bjorn_fogelberg_karooshi_porn-204-233.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-09-bjorn_fogelberg_karooshi_porn-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-10-jeff_wahl_freedom-117-146.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-10-jeff_wahl_freedom-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-10-jeff_wahl_freedom-59-88.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-11-michael_masley_soliel-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-11-michael_masley_soliel-117-146.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-11-michael_masley_soliel-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-11-michael_masley_soliel-59-88.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-12-trip_wamsley_finally-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-12-trip_wamsley_finally-117-146.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-12-trip_wamsley_finally-146-175.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-12-trip_wamsley_finally-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-12-trip_wamsley_finally-233-262.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-12-trip_wamsley_finally-262-291.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-12-trip_wamsley_finally-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-13-jag_juke_joint_boogie-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-13-jag_juke_joint_boogie-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-14-thursday_group_like_white_on_rice-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-14-thursday_group_like_white_on_rice-117-146.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-14-thursday_group_like_white_on_rice-146-175.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-14-thursday_group_like_white_on_rice-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-14-thursday_group_like_white_on_rice-233-262.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-14-thursday_group_like_white_on_rice-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-14-thursday_group_like_white_on_rice-349-378.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-14-thursday_group_like_white_on_rice-59-88.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-15-scott_hill_you_think_too_much-117-146.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-15-scott_hill_you_think_too_much-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-15-scott_hill_you_think_too_much-204-233.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-15-scott_hill_you_think_too_much-30-59.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-16-chris_juergenson_prospects-0-29.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-16-chris_juergenson_prospects-117-146.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-16-chris_juergenson_prospects-175-204.mp3
#   inflating: audio/d/magnatune_compilation-new_age_and_jazz-16-chris_juergenson_prospects-30-59.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-117-146.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-146-175.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-204-233.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-320-349.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-378-407.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-465-494.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-494-523.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-581-610.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-610-639.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-639-668.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-668-697.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-697-726.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-726-755.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-755-784.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-784-813.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-842-871.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-871-900.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-900-929.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-01-night_illusions__the_longing-929-958.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-02-night_illusions__balancing_spheres-146-175.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-02-night_illusions__balancing_spheres-30-59.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-02-night_illusions__balancing_spheres-88-117.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-03-night_illusions__one_path_revealed-117-146.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-03-night_illusions__one_path_revealed-146-175.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-03-night_illusions__one_path_revealed-175-204.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-03-night_illusions__one_path_revealed-233-262.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-03-night_illusions__one_path_revealed-262-291.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-03-night_illusions__one_path_revealed-291-320.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-03-night_illusions__one_path_revealed-59-88.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-03-night_illusions__one_path_revealed-88-117.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-04-day_dreams__the_flames_are_awakened-146-175.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-04-day_dreams__the_flames_are_awakened-175-204.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-04-day_dreams__the_flames_are_awakened-204-233.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-04-day_dreams__the_flames_are_awakened-233-262.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-04-day_dreams__the_flames_are_awakened-262-291.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-04-day_dreams__the_flames_are_awakened-30-59.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-04-day_dreams__the_flames_are_awakened-88-117.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-1016-1045.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-1045-1074.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-1074-1103.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-1103-1132.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-1132-1161.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-1161-1190.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-117-146.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-1190-1219.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-1248-1277.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-175-204.mp3
#   inflating: audio/d/paul_avgerinos-balancing_spheres-05-day_dreams__and_thirst_is_quenched-233-262.mp3
# ...
#   inflating: audio/f/three_holies_church_choristers-the_hymns_of_the_ancient_church-13-sunday_eucharist_chant__byzantine_chant-88-117.mp3
#   inflating: audio/f/thursday_group-first_album-01-innocent_murmur-0-29.mp3
#   inflating: audio/f/thursday_group-first_album-01-innocent_murmur-146-175.mp3
#   inflating: audio/f/thursday_group-first_album-01-innocent_murmur-233-262.mp3
#   inflating: audio/f/thursday_group-first_album-01-innocent_murmur-291-320.mp3
#   inflating: audio/f/thursday_group-first_album-01-innocent_murmur-30-59.mp3
#   inflating: audio/f/thursday_group-first_album-01-innocent_murmur-320-349.mp3
#   inflating: audio/f/thursday_group-first_album-01-innocent_murmur-436-465.mp3
#   inflating: audio/f/thursday_group-first_album-01-innocent_murmur-88-117.mp3
#   inflating: audio/f/thursday_group-first_album-02-winds_eye-0-29.mp3
#   inflating: audio/f/thursday_group-first_album-02-winds_eye-146-175.mp3
#   inflating: audio/f/thursday_group-first_album-02-winds_eye-175-204.mp3
#   inflating: audio/f/thursday_group-first_album-02-winds_eye-233-262.mp3
#   inflating: audio/f/thursday_group-first_album-02-winds_eye-30-59.mp3
#   inflating: audio/f/thursday_group-first_album-02-winds_eye-59-88.mp3
#   inflating: audio/f/thursday_group-first_album-03-lynchs_law-117-146.mp3
#   inflating: audio/f/thursday_group-first_album-03-lynchs_law-175-204.mp3
#   inflating: audio/f/thursday_group-first_album-03-lynchs_law-204-233.mp3
#   inflating: audio/f/thursday_group-first_album-03-lynchs_law-30-59.mp3
#   inflating: audio/f/thursday_group-first_album-03-lynchs_law-59-88.mp3
#   inflating: audio/f/thursday_group-first_album-04-doing_the_the_clown-117-146.mp3
#   inflating: audio/f/thursday_group-first_album-04-doing_the_the_clown-146-175.mp3
#   inflating: audio/f/thursday_group-first_album-04-doing_the_the_clown-175-204.mp3
#   inflating: audio/f/thursday_group-first_album-04-doing_the_the_clown-349-378.mp3
#   inflating: audio/f/thursday_group-first_album-05-rainy_season-117-146.mp3
#   inflating: audio/f/thursday_group-first_album-05-rainy_season-233-262.mp3
#   inflating: audio/f/thursday_group-first_album-05-rainy_season-291-320.mp3
#   inflating: audio/f/thursday_group-first_album-06-oaks-146-175.mp3
#   inflating: audio/f/thursday_group-first_album-06-oaks-204-233.mp3
#   inflating: audio/f/thursday_group-first_album-06-oaks-233-262.mp3
#   inflating: audio/f/thursday_group-first_album-07-claytonia-0-29.mp3
#   inflating: audio/f/thursday_group-first_album-07-claytonia-175-204.mp3
#   inflating: audio/f/thursday_group-first_album-07-claytonia-204-233.mp3
#   inflating: audio/f/thursday_group-first_album-07-claytonia-233-262.mp3
#   inflating: audio/f/thursday_group-first_album-07-claytonia-262-291.mp3
#   inflating: audio/f/thursday_group-first_album-07-claytonia-30-59.mp3
#   inflating: audio/f/thursday_group-first_album-07-claytonia-320-349.mp3
#   inflating: audio/f/thursday_group-first_album-07-claytonia-436-465.mp3
#   inflating: audio/f/thursday_group-first_album-07-claytonia-88-117.mp3
#   inflating: audio/f/thursday_group-first_album-08-sweet_pea-0-29.mp3
#   inflating: audio/f/thursday_group-first_album-08-sweet_pea-204-233.mp3
#   inflating: audio/f/thursday_group-first_album-08-sweet_pea-233-262.mp3
#   inflating: audio/f/thursday_group-first_album-08-sweet_pea-291-320.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-0-29.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-117-146.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-146-175.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-204-233.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-233-262.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-262-291.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-291-320.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-30-59.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-349-378.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-378-407.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-59-88.mp3
#   inflating: audio/f/tilopa-turkishauch-01-1x3-88-117.mp3
#   inflating: audio/f/tilopa-turkishauch-02-meifrui_i-146-175.mp3
#   inflating: audio/f/tilopa-turkishauch-02-meifrui_i-175-204.mp3
#   inflating: audio/f/tilopa-turkishauch-02-meifrui_i-204-233.mp3
#   inflating: audio/f/tilopa-turkishauch-02-meifrui_i-233-262.mp3
#   inflating: audio/f/tilopa-turkishauch-02-meifrui_i-262-291.mp3
#   inflating: audio/f/tilopa-turkishauch-02-meifrui_i-320-349.mp3
#   inflating: audio/f/tilopa-turkishauch-02-meifrui_i-349-378.mp3
#   inflating: audio/f/tilopa-turkishauch-02-meifrui_i-59-88.mp3
#   inflating: audio/f/tilopa-turkishauch-02-meifrui_i-88-117.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-0-29.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-146-175.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-175-204.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-204-233.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-233-262.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-262-291.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-291-320.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-30-59.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-349-378.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-407-436.mp3
#   inflating: audio/f/tilopa-turkishauch-03-avanti-436-465.mp3
#   inflating: audio/f/tilopa-turkishauch-04-glasrohrstuck-0-29.mp3
#   inflating: audio/f/tilopa-turkishauch-04-glasrohrstuck-117-146.mp3
#   inflating: audio/f/tilopa-turkishauch-04-glasrohrstuck-146-175.mp3
#   inflating: audio/f/tilopa-turkishauch-04-glasrohrstuck-291-320.mp3
#   inflating: audio/f/tilopa-turkishauch-04-glasrohrstuck-30-59.mp3
#   inflating: audio/f/tilopa-turkishauch-04-glasrohrstuck-320-349.mp3
#   inflating: audio/f/tilopa-turkishauch-04-glasrohrstuck-378-407.mp3
#   inflating: audio/f/tilopa-turkishauch-04-glasrohrstuck-59-88.mp3
#   inflating: audio/f/tilopa-turkishauch-04-glasrohrstuck-88-117.mp3
#   inflating: audio/f/tilopa-turkishauch-05-schlicht_1-117-146.mp3
#   inflating: audio/f/tilopa-turkishauch-05-schlicht_1-175-204.mp3
#   inflating: audio/f/tilopa-turkishauch-05-schlicht_1-204-233.mp3
#   inflating: audio/f/tilopa-turkishauch-05-schlicht_1-349-378.mp3
#   inflating: audio/f/tilopa-turkishauch-05-schlicht_1-88-117.mp3
#   inflating: audio/f/tilopa-turkishauch-06-2x2-117-146.mp3
#   inflating: audio/f/tilopa-turkishauch-06-2x2-204-233.mp3
#   inflating: audio/f/tilopa-turkishauch-06-2x2-233-262.mp3
#   inflating: audio/f/tilopa-turkishauch-06-2x2-291-320.mp3
#   inflating: audio/f/tilopa-turkishauch-06-2x2-30-59.mp3
#   inflating: audio/f/tilopa-turkishauch-06-2x2-59-88.mp3
#   inflating: audio/f/tilopa-turkishauch-06-2x2-88-117.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-0-29.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-146-175.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-175-204.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-233-262.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-291-320.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-30-59.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-320-349.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-349-378.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-378-407.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-407-436.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-465-494.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-523-552.mp3
#   inflating: audio/f/tilopa-turkishauch-07-meifrui_ii-552-581.mp3
#   inflating: audio/f/tilopa-turkishauch-08-hifumichor-0-29.mp3
#   inflating: audio/f/tilopa-turkishauch-08-hifumichor-175-204.mp3
#   inflating: audio/f/tilopa-turkishauch-08-hifumichor-204-233.mp3
#   inflating: audio/f/tilopa-turkishauch-08-hifumichor-233-262.mp3
#   inflating: audio/f/tilopa-turkishauch-08-hifumichor-262-291.mp3
#   inflating: audio/f/tilopa-turkishauch-08-hifumichor-291-320.mp3
#   inflating: audio/f/tilopa-turkishauch-08-hifumichor-30-59.mp3
#   inflating: audio/f/tilopa-turkishauch-08-hifumichor-320-349.mp3
#   inflating: audio/f/tilopa-turkishauch-08-hifumichor-88-117.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-01-making_me_nervous_brad_sucks-30-59.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-02-at_least_youve_been_told_arthur_yoria-146-175.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-02-at_least_youve_been_told_arthur_yoria-59-88.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-02-at_least_youve_been_told_arthur_yoria-88-117.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-03-completely_mysticism_dr_kuch-0-29.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-03-completely_mysticism_dr_kuch-175-204.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-03-completely_mysticism_dr_kuch-204-233.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-03-completely_mysticism_dr_kuch-30-59.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-03-completely_mysticism_dr_kuch-59-88.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-04-burn_bright_burn_fast_electric_frankentstein-0-29.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-04-burn_bright_burn_fast_electric_frankentstein-146-175.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-04-burn_bright_burn_fast_electric_frankentstein-175-204.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-04-burn_bright_burn_fast_electric_frankentstein-30-59.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-04-burn_bright_burn_fast_electric_frankentstein-88-117.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-05-unknown_emmas_mini-117-146.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-05-unknown_emmas_mini-146-175.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-05-unknown_emmas_mini-175-204.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-05-unknown_emmas_mini-262-291.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-06-alchemy_cargo_cult-0-29.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-06-alchemy_cargo_cult-146-175.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-06-alchemy_cargo_cult-175-204.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-06-alchemy_cargo_cult-204-233.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-06-alchemy_cargo_cult-233-262.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-06-alchemy_cargo_cult-262-291.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-06-alchemy_cargo_cult-291-320.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-06-alchemy_cargo_cult-30-59.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-06-alchemy_cargo_cult-59-88.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-07-i_dont_care_if_you_lie_c_layne-146-175.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-07-i_dont_care_if_you_lie_c_layne-59-88.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-07-i_dont_care_if_you_lie_c_layne-88-117.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-08-so_gone_myles_cochran-146-175.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-08-so_gone_myles_cochran-204-233.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-08-so_gone_myles_cochran-291-320.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-08-so_gone_myles_cochran-320-349.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-08-so_gone_myles_cochran-378-407.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-08-so_gone_myles_cochran-59-88.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-09-and_come_the_sirens_jade_leary-0-29.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-09-and_come_the_sirens_jade_leary-204-233.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-09-and_come_the_sirens_jade_leary-233-262.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-09-and_come_the_sirens_jade_leary-262-291.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-09-and_come_the_sirens_jade_leary-88-117.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-10-remedy_lizzi-0-29.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-10-remedy_lizzi-117-146.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-10-remedy_lizzi-233-262.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-10-remedy_lizzi-262-291.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-10-remedy_lizzi-291-320.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-10-remedy_lizzi-88-117.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-11-cuckoo_lisa_debenedictis-146-175.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-11-cuckoo_lisa_debenedictis-175-204.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-11-cuckoo_lisa_debenedictis-204-233.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-11-cuckoo_lisa_debenedictis-233-262.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-11-cuckoo_lisa_debenedictis-59-88.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-12-wreck_of_the_zephyr_drop_trio-117-146.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-12-wreck_of_the_zephyr_drop_trio-175-204.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-12-wreck_of_the_zephyr_drop_trio-30-59.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-12-wreck_of_the_zephyr_drop_trio-88-117.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-13-til_my_cup_runs_over_four_stones-117-146.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-13-til_my_cup_runs_over_four_stones-59-88.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-13-til_my_cup_runs_over_four_stones-88-117.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-14-flying_sun_palace-117-146.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-14-flying_sun_palace-175-204.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-14-flying_sun_palace-30-59.mp3
#   inflating: audio/f/various_artists-south_by_southwest_compilation-14-flying_sun_palace-88-117.mp3
# --2022-02-28 16:56:16--  http://www.ifs.tuwien.ac.at/~vogl/other/feat_cache.npy
# Resolving www.ifs.tuwien.ac.at (www.ifs.tuwien.ac.at)... 128.131.167.11
# Connecting to www.ifs.tuwien.ac.at (www.ifs.tuwien.ac.at)|128.131.167.11|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2022-02-28 16:56:17 ERROR 403: Forbidden.
#
# --2022-02-28 16:56:17--  http://www.ifs.tuwien.ac.at/~vogl/other/name_cache.npy
# Resolving www.ifs.tuwien.ac.at (www.ifs.tuwien.ac.at)... 128.131.167.11
# Connecting to www.ifs.tuwien.ac.at (www.ifs.tuwien.ac.at)|128.131.167.11|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2022-02-28 16:56:17 ERROR 403: Forbidden.
#
# ===================
# Make sure you activated GPU support: Edit->Notebook settings->Hardware acceleration->GPU
# ==================

# %% [markdown]
# ## Task 1: Dataset Preparation (20 Points)
#
# From the MagnaTagATune dataset Website, use the clip metadata, the zag
# annotations, and the audio data files. To save storage on the cluster, we already downloaded the files into the shared folder at: `~/shared/data/assignment_6/`
#
# Next, prepare the data in a way that allows to train a neural network and test performance:
# 1. Extract features for the audio files (logarithmic mel-frequency spectrograms).
# 2. Generating a training/validation/test split using the provided split definitions (Important: Use the information given in the clip metadata file to ensure that no clips extracted from the same track end up in different splits).
# 3. Filter the tags such that only the 50 most frequent tags in the dataset remain.

# %%
import os
import numpy as np

# get dataset path
dataset_path = os.path.join(os.environ['HOME'], 'shared', 'data', 'assignment_6')
if os.path.exists('audio'):
    dataset_path = '.'

audio_path = os.path.join(dataset_path, 'audio')
cache_path = os.path.join(dataset_path, 'cache')

data_file_clip_info = os.path.join(dataset_path, 'clip_info_final.csv')
data_file_annotations = os.path.join(dataset_path, 'annotations_final.csv')

# collect list of audio files:
sub_paths = os.listdir(audio_path)
audio_file_paths = []
for sub_path in sub_paths:
    cur_path = os.path.join(audio_path, sub_path)
    if not os.path.isdir(cur_path):
        continue
    audio_files = [af for af in os.listdir(cur_path) if af.endswith('.mp3')]
    audio_file_paths.extend([os.path.join(audio_path, sub_path, af) for af in audio_files])

audio_file_total_count = len(audio_file_paths)

print(f'Total number of audio files: {audio_file_total_count}')
# Out:
# Total number of audio files: 25863

# %% [markdown]
# ### 1.1 Feature Extraction
#
# Iterate over the audio files and extract log mel-frequency spectrograms. You can use madmom or librose, and are free to copy your code from previous assignments. Make sure to use the provided variables, in order for the automated tests to pass.
#
# Since we are interested in global properties, Choi et al. \[2016\] uses parameters that result in a more coarse spectrogram. Additionally all audio files are in the dataset should have the common length of 29.1s, which results in feature matrices with a fixed shape.

# %%
audio_len = 29.124
sample_rate = 12000
fft_frame_size = 512
num_mel_bands = 96
hop_size = 256

exp_feat_shape = (96, 1366)

# %% [markdown]
# **Implement the function below to extract the features from the list of audio files.** You can use `madmom` or `librosa` to extract the mel spectrograms. Be aware of the different ordering of dimensions for frequency bins and time of the two frameworks.
#
# **Note:** Make sure to be able to handle corrupt audio files (e.g. try/except block), there are a couple of corrupt audio files in the dataset.

# %%
def extract_features(file_list):
    features = []  # list containing features for each audio file
    file_names = []  # audio file names for features (indices should correspond!), cut path and file extension, only leave names
    # iterate over files and extract features...
    # YOUR CODE HERE
    
    for file in file_list:
        try:
            signal_audio, sr  = librosa.load(file, sr = sample_rate)
            mel_spectrogram = librosa.feature.melspectrogram(y=signal_audio, sr=sample_rate,n_fft = fft_frame_size,
                                                          hop_length = hop_size,n_mels=num_mel_bands)
            features.append(librosa.power_to_db(mel_spectrogram))
            file_names.append(Path(file).stem)
        except:
            continue
    
    features = np.asarray(features)
    print(features.shape)
    
    return np.asarray(features), np.asarray(file_names)

# %%
# tests

from time import time as get_time

t1 = get_time()
num_test_files = 10
test_feats, test_names = extract_features(audio_file_paths[:num_test_files])
t_calc = get_time()-t1
print(f"Calculating features for {num_test_files} files took: {t_calc:.2f}s. Full dataset ({audio_file_total_count}) will take: {t_calc/num_test_files*audio_file_total_count:.2f}s.")

assert len(test_feats) == num_test_files, "not all features calculated!"
assert all([cur_feat.shape == exp_feat_shape for cur_feat in test_feats]), "incorrect features shape!"

print('All tests successful!')
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   frame_duration = -1
# (10, 96, 1366)
# Calculating features for 10 files took: 20.10s. Full dataset (25863) will take: 51979.58s.
# All tests successful!

# %% [markdown]
# As you can see from the test above, extracting the features takes quite some time. To save you the time when restarting the kernel, and/or save disk space on the cluster, we already cached the features and stored them in a numpy file. If you run this notebook somewhere else (e.g. Colab), be prepared that the feature extraction will take significant time.
# You can also copy the numpy arrays if this is faster than recalculating all features. Also be aware that the cached features file is approximately 14GB.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls "/content/drive/MyDrive/audio/"

feat_path = "/content/drive/MyDrive/audio/"

feat_cache_file = os.path.join(feat_path, 'feat_cache.npy')
name_cache_file = os.path.join(feat_path, 'name_cache.npy')
if not os.path.exists(feat_cache_file) or not os.path.exists(name_cache_file):
    t1 = get_time()
    features, file_names = extract_features(audio_file_paths)
    np.save(feat_cache_file, features)
    np.save(name_cache_file, file_names)
    print(f"Recalculated all features. Took: {get_time()-t1} seconds.")
else:
    features = np.load(feat_cache_file, allow_pickle=True, mmap_mode='r')
    file_names = np.load(name_cache_file, allow_pickle=True, mmap_mode='r')
    print(f"Loaded feature cache. ")
# Out:
# Mounted at /content/drive
# feat_cache.npy	name_cache.npy
# Loaded feature cache.

# %% [markdown]
# The next cell is a workaround for the limited infrastructure. If you have enough hardware resources, you can run the example with the full data.

# %%
# subsample features and names to make data size more manageable.
# if you have powerful infrastructure you can run with full data and set use_subsample to False.

use_subsample = True
data_size = len(features)

if use_subsample:
    indices = list(range(data_size))

    fraction = 0.25
    data_size = int(data_size * fraction)
    import random
    random.shuffle(indices)
    indices = indices[:data_size]

    features = features[indices]
    file_names = file_names[indices]

data_size = len(features)
print(f'number of datapoints: {data_size}')
# Out:
# number of datapoints: 1616

# %%
# test

assert features[0].shape == (96, 1366)

print('All tests successful!')
# Out:
# All tests successful!

# %% [markdown]
# ### 1.2 Collect and Preprocess Tags
#
# The file referenced by `data_file_annotations` contains the annotations of the dataset. It is a comma-separated-values file (csv), you can use e.g. the python package [`csv`](https://docs.python.org/3/library/csv.html) or [`pandas`](https://pandas.pydata.org/docs/user_guide/10min.html) to open and work on the data. Note that `csv` is simple and easy to use, but offers little data handling support, while `pandas` is more complex but also more powerful.
# Once you loaded the data from the file, inspect the data. You will find, that each row represents an audio clip, and there are columns for each annotated tag, as well as for the path to the audio file `mp3_path` and some unique ID `clip_id`.
# Extract all tags, gather a set of unique tags, and count how often each tag is used.
# Then only keep the 50 most frequent tags `most_freq_tags`.
#
# The returned list of tags represents our classes, and indices in this list represent the unique ID for the corresponding class - so after the definition of the `class_names` list, do not change the order of this list later in the notebook, and reference classes / class labels as indices of this list / names in this list.
#
# **Implement the function below to build the list of class names and training targets.**

# %%
DEFAULT_NUM_CLASSES = 50

# %%
def create_targets(num_classes = DEFAULT_NUM_CLASSES, annot_file=data_file_annotations):
    # read annotations from data_file_annotations
    # extract 50 most frequent tags
    most_freq_tags = []  #TODO: fill with most frequent tags
    class_names = most_freq_tags

    # buld targets for the neural network training:
    # creat an array with binary on/off values for each tag in most_freq_tags (target array); 
    # create these target arrays for each of the rows in the annotation file.
    # each row in the annotation file references a audio file ('clip_id' / 'mp3_path').
    # store an entry in the dictionary below using the audio name ('mp3_path' column without path and extension, 
    # as for the features list) as key and the target array as value
    targ_dict = {}  #TODO: fill with targets
    
    # YOUR CODE HERE
    
    annotations = pd.read_csv(data_file_annotations, sep='\t')
    all_class_names = annotations.columns.values
    
    counting = {}
    for name in all_class_names:
        counting[name] = 0
    
    for index, row in annotations.iterrows():
        for name in all_class_names:
            if(row[name] == 1):
                counting[name] += 1
    
    sorted_classes = {k: v for k, v in sorted(counting.items(), key=lambda item: item[1], reverse = True)}
    
    sorted_classes_top = list(sorted_classes.keys())[:50]
    
    most_freq_tags = sorted_classes_top
    class_names = most_freq_tags
    
    for index, row in annotations.iterrows():
        annot = []
        for cl in class_names:
            annot.append(row[cl])
        #print(Path(row['mp3_path']).stem)
        targ_dict[Path(row['mp3_path']).stem] = np.asarray(annot)
    
    print(type(targ_dict))
    
    return class_names, targ_dict

# %%
class_names, targ_dict = create_targets()

print(f'most frequent tags: {class_names}')
# Out:
# <class 'dict'>
# most frequent tags: ['guitar', 'classical', 'slow', 'techno', 'strings', 'drums', 'electronic', 'rock', 'fast', 'piano', 'ambient', 'beat', 'violin', 'vocal', 'synth', 'female', 'indian', 'opera', 'male', 'singing', 'vocals', 'no vocals', 'harpsichord', 'loud', 'quiet', 'flute', 'woman', 'male vocal', 'no vocal', 'pop', 'soft', 'sitar', 'solo', 'man', 'classic', 'choir', 'voice', 'new age', 'dance', 'male voice', 'female vocal', 'beats', 'harp', 'cello', 'no voice', 'weird', 'country', 'female voice', 'metal', 'choral']

# %%
# tests

assert len(class_names) == DEFAULT_NUM_CLASSES

assert len(targ_dict.keys()) >= audio_file_total_count

assert next(iter(targ_dict.values())).shape == (DEFAULT_NUM_CLASSES, ), f"invalid shape for targets, expected ({DEFAULT_NUM_CLASSES}, )"

print('All tests successful!')
# Out:
# All tests successful!

# %% [markdown]
# ### Task 1.3 Generating Dataset Splits
# Divide the data into training, validation, and test splits. For validation use approximately 5% and for testing hold out approximately 15% of the total data.
# Consider that there maybe be multiple clips of the same track. Different clips of the same track must be in the same split (all in either train, valid, or test), to counteract overfitting.
#
# To identify the individual tracks and clips of the same track, we need to look into the file `'clip_info_final.csv'`. The path to this file is stored in `data_file_clip_info`.
#
# You can identify individual tracks by their `original_url` column, however, for some files the `original_url` is not provided. So to be save, use a combination of the following columns to identify unique entries: `["track_number", "title", "artist", "album", "url", "original_url"]`.
# Note that individual tracks will have a varying count of clips.
#
# The easiest way to divide the data into train, valid, and test split, is to divide the tracks (unique rows from above) into the splits, and assume that the number of clips will average out over all tracks, so that in the end we get approximately the desired split sizes (the exact number is not so important). You are free to accomplish this in any other way if you prefer.

# %%
DEFAULT_TEST_PERC = 0.15
DEFAULT_VALID_PERC = 0.05

# %%
# to split features, targets, and names into train, valid, and test split, it is easiest to just 
# generate indices to our overall feature/name/target lists.
# the indices should be randomly drawn, but also put samples of the same original track in the same split.
# feel free to change this cell, if you choose to define your splits in another way.

def get_split_indices(file_names_list, clip_info_file, 
                      test_perc=DEFAULT_TEST_PERC, valid_perc=DEFAULT_VALID_PERC):
    train_perc = 1-test_perc-valid_perc
    
    # YOUR CODE HERE
    test_indcs = []
    train_indcs = []
    valid_indcs = []
    
    tracks = pd.read_csv(clip_info_file, sep='\t')

    files = []
    for file in file_names_list:
        files.append(file.split('-'))
  

    unassigned = file_names_list
    
    for index, row in tracks.iterrows():
        
        pick = randrange(0,100)
        if(pick < DEFAULT_VALID_PERC*100):
            set_choice = "valid"
        elif(pick < (DEFAULT_TEST_PERC*100 + DEFAULT_VALID_PERC*100)):
            set_choice = "test"    
        else:
            set_choice = "train"
        
        name = row['mp3_path']
        
        if isinstance(name, str):
            name = row['mp3_path'][2:-4]
            if name in file_names_list:
                i = file_names_list.index(name)
                if(i not in test_indcs and i not in train_indcs and i not in valid_indcs):
                    if(set_choice == "test"):
                        test_indcs.append(i)
                    if(set_choice == "valid"):
                        valid_indcs.append(i)
                    if(set_choice == "train"):
                        train_indcs.append(i)
                else:
                    print(name)
                    
    print(len(test_indcs))
    print(len(valid_indcs))
    print(len(train_indcs))
    print(len(file_names_list))

    
    return test_indcs, valid_indcs, train_indcs

# %%
# feel free to change this, if you define your splits other than by indices...

test_indcs, valid_indcs, train_indcs = get_split_indices(list(file_names), data_file_clip_info)

test_feats = features[test_indcs]
valid_feats = features[valid_indcs]
train_feats = features[train_indcs]

test_names = file_names[test_indcs]
valid_names = file_names[valid_indcs]
train_names = file_names[train_indcs]

train_targs = np.asarray([targ_dict[cur_name] for cur_name in train_names])
valid_targs = np.asarray([targ_dict[cur_name] for cur_name in valid_names])
test_targs = np.asarray([targ_dict[cur_name] for cur_name in test_names])
# Out:
# 253
# 76
# 1287
# 1616

# %%
# tests

tmp_test_perc=DEFAULT_TEST_PERC
tmp_valid_perc=DEFAULT_VALID_PERC
tmp_train_perc = 1-tmp_test_perc-tmp_valid_perc

# we assume for spliting by tracks, that the split sizes should be within +-20%
assert int(data_size*tmp_train_perc*0.8) <= len(train_indcs) \
                        <= int(data_size*tmp_train_perc*1.2)
assert int(data_size*tmp_valid_perc*0.8) <= len(valid_indcs) \
                        <= int(data_size*tmp_valid_perc*1.2)
assert int(data_size*tmp_test_perc*0.8) <= len(test_indcs) \
                        <= int(data_size*tmp_test_perc*1.2)

print('All tests successful!')
# Out:
# All tests successful!

# %% [markdown]
# ### 1.4 Dataset Class
#
# **Implement a torch dataset** as we did for assignment 5. In this case the dataset is quite simple, since we will return one file as one training example.
# The total count, therefore, is the length of the feature list, and the `getitem` method should just return the feature/target combination at the provided index.
# Remember to convert the return values for `getitem` to torch tensors.

# %%
import torch
from torch.utils.data import Dataset

if not COLAB:
    torch.set_num_threads(16)  # we have to set the number of threads < 64, this is a workaround

# %%
class MagnaSet(Dataset):
    def __init__(self, features, targets):
        super(MagnaSet, self).__init__()
        # YOUR CODE HERE
        self.features = features
        self.targets = targets
        
        self.length = len(features)

    def __len__(self):
        # YOUR CODE HERE
        return self.length

    def __getitem__(self, idx):
        # YOUR CODE HERE
        features_ret = self.features[idx].astype(np.float32)
        targets_ret = self.targets[idx].astype(np.float32)
        data = (torch.tensor(features_ret), torch.tensor(targets_ret))
        #data_tensor = torch.tensor(data)
        return data

# %%
# tests
tmp_num_samples = 100
tmp_test_feats = np.asarray([np.random.rand(*exp_feat_shape) for _ in range(tmp_num_samples)])
tmp_test_targs = np.asarray([np.random.rand(DEFAULT_NUM_CLASSES) for _ in range(tmp_num_samples)])

tmp_test_dataset = MagnaSet(tmp_test_feats, tmp_test_targs)

assert len(tmp_test_dataset) == tmp_num_samples, "dataset returns wrong length"

tmp_ex_feat, tmp_ex_targ = tmp_test_dataset[10]
assert tmp_ex_feat.shape == exp_feat_shape
assert tmp_ex_targ.shape == (DEFAULT_NUM_CLASSES, )
assert np.allclose(tmp_ex_feat, tmp_test_feats[10])
tmp_ex_feat, tmp_ex_targ = tmp_test_dataset[0]
assert tmp_ex_feat.shape == exp_feat_shape
assert tmp_ex_targ.shape == (DEFAULT_NUM_CLASSES, )
assert np.allclose(tmp_ex_feat, tmp_test_feats[0])
tmp_ex_feat, tmp_ex_targ = tmp_test_dataset[tmp_num_samples-1]
assert tmp_ex_feat.shape == exp_feat_shape
assert tmp_ex_targ.shape == (DEFAULT_NUM_CLASSES, )
assert np.allclose(tmp_ex_feat, tmp_test_feats[tmp_num_samples-1])

try:
    tmp_ex_feat, tmp_ex_targ = tmp_test_dataset[tmp_num_samples]
    assert False, "this should produce an out of index error!"
except:
    assert True

print('All tests successful!')
# Out:
# All tests successful!

# %% [markdown]
# ## Task 2: Neural Network Implementaion (5 Points)
#
# Implement the neural network architecture outlined by Choi et al. \[2016\]. The model usees the Mel-spectrograms as inputs and produces a 50-value vector as output (representing the probabilities for labels). Since multiple labels can apply, sigmoid outputs should be used.
#
# Note that the FCN-4 architecture described in the paper lacks implementation details and is revisited in the github repository to the paper. So, instead follow the MusicTaggerCNN [KERAS reference implementation](https://github.com/keunwoochoi/music-auto_tagging-keras/blob/master/music_tagger_cnn.py) by the same authors to reproduce the architecture using pyTorch.
#
# The architecture consists of 5 CNN layers (with 3x3 kernels all; and 64, 128, 128, 128, 64 channels respectively), and a fully connected output layer with 50 nodes. Use batch-normalization and max-pooling (with 2x4, 2x4, 2x4, 3x5, 4x4 kernels) after each convolutional layer, and as activation functions use ELU (`torch_func.elu`).
#
# **Implement the pytorch network below.**

# %%
import torch.nn as nn
import torch.nn.functional as torch_func

class MusicTaggerCNN(nn.Module):
    def __init__(self, debug=False, num_classes=DEFAULT_NUM_CLASSES):
        super(MusicTaggerCNN, self).__init__()
        self.debug = debug # use the debug flag again to produce shape outputs in the forward function.
        
        #initialize modules for neural network
        
        # 1st Convolutional layer
        #2D Convolution, channels: 64, kernel: 3x3
        self.conv1 = nn.Conv2d(1, 64, kernel_size = (3, 3), padding = 1)
        #2D Batchnorm, channels: 32
        self.conv1_bn = nn.BatchNorm2d(64)

        
        # 2nd Convolutional layer
        #2D Convolution, channels (in/out): 128, kernel: 3x3
        self.conv2 = nn.Conv2d(64, 128, kernel_size=(3,3), padding = 1)
        #2D Batchnorm, channels: 128
        self.conv2_bn = nn.BatchNorm2d(128)
       
        
       
         # 3rd Convolutional layer
        #2D Convolution, channels: 32/32, kernel: 3x3
        self.conv3 = nn.Conv2d(128, 128, kernel_size = (3,3), padding = 1)
        #2D Batchnorm, channels: 128
        self.conv3_bn = nn.BatchNorm2d(128)
        ## ELU
        # MaxPool layer
        
        
        # 4th Convolutional layer
        #2D Convolution, channels: 128/64, kernel: 3x3
        self.conv4 = nn.Conv2d(128, 128, kernel_size = (3,3), padding = 1)
        #2D Batchnorm, channels: 128
        self.conv4_bn = nn.BatchNorm2d(128)
        ## ELU
        # MaxPool layer
        
        # 5th Convolutional layer
        #2D Convolution, channels: 32/32, kernel: 3x3
        self.conv5 = nn.Conv2d(128, 64, kernel_size = (3,3), padding = 1)
        #2D Batchnorm, channels: 64
        self.conv5_bn = nn.BatchNorm2d(64)
        ## ELU
        # MaxPool layer
        
        # output layer
        self.dense_out = nn.Linear(64, 50)

    def forward(self, x):
        x = x.unsqueeze(1)
        # YOUR CODE HERE
        if self.debug:   #### ADDED
          print("input layer")
          print(x.shape)
        # 1
        h = self.conv1(x) # apply convolution
        h = self.conv1_bn(h) # apply batch norm
        h = torch_func.elu(h)
        h = torch_func.max_pool2d(h, kernel_size = (2,4))
        if self.debug:   #### ADDED
            print("first layer")
            print(h.shape)

        # 2
        h = self.conv2(h) # apply convolution
        h = self.conv2_bn(h) # apply batch norm
        h = torch_func.elu(h)
        h = torch_func.max_pool2d(h, kernel_size = (2,4))
        if self.debug:    #### ADDED
          print("second layer")
          print(h.shape)

        # 3
        h = self.conv3(h) # apply convolution
        h = self.conv3_bn(h) # apply batch norm
        h = torch_func.elu(h)
        h = torch_func.max_pool2d(h, kernel_size = (2,4))
        if self.debug:    #### ADDED
          print("third layer")
          print(h.shape)

        # 4
        h = self.conv4(h) # apply convolution
        h = self.conv4_bn(h) # apply batch norm
        h = torch_func.elu(h)
        h = torch_func.max_pool2d(h, kernel_size = (3,5))
        if self.debug:    #### ADDED
          print("fourth layer")
          print(h.shape)

        # 5
        h = self.conv5(h) # apply convolution
        h = self.conv5_bn(h) # apply batch norm
        h = torch_func.elu(h)
        h = torch_func.max_pool2d(h, kernel_size = (4,4))
        if self.debug:    #### ADDED
          print("fifth layer")
          print(h.shape)
        
        y = h.view(-1, 64)
        y = self.dense_out(y)
        y = torch_func.sigmoid(y)
        #y = h.view(-1, 50)
        if self.debug:    #### ADDED
          print("output shape")
          print(y.shape)
        
        
        return y

# %%
# tests
net = MusicTaggerCNN(debug=True)

batches = 1
output = net.forward(torch.rand(batches, *exp_feat_shape))
assert output.shape == (batches, DEFAULT_NUM_CLASSES)
batches = 20
output = net.forward(torch.rand(batches, *exp_feat_shape))
assert output.shape == (batches, DEFAULT_NUM_CLASSES)

module_list = net.__dict__['_modules'].values()

num_modules = len(module_list)
assert num_modules == 11, "expected 11 modules!"

num_conv2d = 0
num_bn2d = 0
num_lin = 0
# count modules...
print("Found modules:")
for idx, module in enumerate(module_list):
    print("{}:\t{}".format(idx+1, module))
    if isinstance(module, nn.Conv2d):
        num_conv2d += 1
    if isinstance(module, nn.BatchNorm2d):
        num_bn2d += 1
    if isinstance(module, nn.Linear):
        num_lin += 1
print('-----------')

assert num_conv2d == 5, "expected 5 2D convolutional layers!"
assert num_bn2d == 5, "expected 5 2D batchnorm layers!"
assert num_lin == 1, "expected 1 dense layers!"

print('All tests successful!')
# Out:
# input layer
# torch.Size([1, 1, 96, 1366])
# first layer
# torch.Size([1, 64, 48, 341])
# second layer
# torch.Size([1, 128, 24, 85])
# third layer
# torch.Size([1, 128, 12, 21])
# fourth layer
# torch.Size([1, 128, 4, 4])
# fifth layer
# torch.Size([1, 64, 1, 1])
# output shape
# torch.Size([1, 50])
# input layer
# torch.Size([20, 1, 96, 1366])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# first layer
# torch.Size([20, 64, 48, 341])
# second layer
# torch.Size([20, 128, 24, 85])
# third layer
# torch.Size([20, 128, 12, 21])
# fourth layer
# torch.Size([20, 128, 4, 4])
# fifth layer
# torch.Size([20, 64, 1, 1])
# output shape
# torch.Size([20, 50])
# Found modules:
# 1:	Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2:	BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 3:	Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 4:	BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 5:	Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 6:	BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 7:	Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 8:	BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 9:	Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 10:	BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 11:	Linear(in_features=64, out_features=50, bias=True)
# -----------
# All tests successful!

# %% [markdown]
# ## Task 3: Network Training (10 Points)
#
# Train the network using ADAM optimization and binary cross-entropy as loss function.
# Whenever applicable, you can reuse code you built for assignment 5, if you want.
#
# ### 3.1 Functions for Training, Testing, and Inference
#
# Very similar to assignment 5, **implement the soubroutines below** to make the main training function more readable:

# %%
# helper functions for training - you can copy and modify from the last assignment

from time import time as get_time


def train_epoch_cnn(model, train_loader, optimizer, args):
    # performs one epoch of training
    model.train()  # set model to training mode (activate dropout layers for example)
    t = get_time() # we measure the needed time
    for batch_idx, (data, target) in enumerate(train_loader):  # iterate over training data
        data, target = data.to(args.device), target.to(args.device)  # move data to device (GPU) if necessary
        optimizer.zero_grad()  # reset optimizer
        output = model(data)   # forward pass: calculate output of network for input
        loss = torch_func.binary_cross_entropy(output, target)  # calculate loss
        loss.backward()  # backward pass: calculate gradients using automatic diff. and backprop.
        optimizer.step()  # udpate parameters of network using our optimizer
        cur_time = get_time()
        # print some outputs if we reached our logging intervall
        if cur_time - t > args.log_interval or batch_idx == len(train_loader)-1:  
            print('[{}/{} ({:.0f}%)]\tloss: {:.6f}, took {:.2f}s'.format(
                       batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss.item(),cur_time - t))
            t = cur_time




def test_cnn(model, test_loader, args):
    # runs inference over the test dataset and calculates overall loss (for validation and testing)
    # YOUR CODE HERE
    model.eval()  # set model to inference mode (deactivate dropout layers for example)
    test_loss = 0  # init overall loss
    with torch.no_grad():  # do not calculate gradients since we do not want to do updates
        for data, target in test_loader:  # iterate over test data
            data, target = data.to(args.device), target.to(args.device)  # move data to device 
            output = model(data) # forward pass
            # claculate loss and add it to our cumulative loss
            test_loss += torch_func.binary_cross_entropy(output, target, reduction='sum').item()
    test_loss /= len(test_loader.dataset)  # calc mean loss
    print('Average eval loss: {:.4f}\n'.format(test_loss, len(test_loader.dataset)))
    return test_loss


def inference_cnn(model, data, args):
   # runs inference over a single instance (for actual use of the model on real data)
    model.eval()   # set model to inference mode
    # reserve output memory
    data_in = torch.from_numpy(data)
    data_in = data_in.unsqueeze(0)
    data_in = data_in.to(args.device)
    
    with torch.no_grad():
        output = model(data_in).cpu()
    
    output = output.numpy().squeeze(0)
    
    return output

# %% [markdown]
# ### 3.2 Hyperparameters
#
# In this assignment a set of hyperparameters is provided. These should work more or less, so there is no need to invest time for an usable first results.
# If you feel like it, you can play around with them once you have a running model.

# %%
# training hyper parameters: go with these defaults at first

CNN_MODEL_NAME = 'cnn_tagger_'

# Helper class for neural network hyper-parameters
# Do not change them until you have a working model
class Args:
    pass

DEFAULT_ARGS = Args()
# general params
DEFAULT_ARGS.use_cuda = True
DEFAULT_ARGS.seed = 1

# architecture setup
DEFAULT_ARGS.batch_size = 36
DEFAULT_ARGS.out_num = DEFAULT_NUM_CLASSES

# optimizer parameters
DEFAULT_ARGS.lr = 0.1

# training protocoll
DEFAULT_ARGS.max_epochs = 1000
DEFAULT_ARGS.patience = 3
DEFAULT_ARGS.refinement = 2  # restart training after patience runs out with the best model, decrease lr by...
DEFAULT_ARGS.lr_fac = 0.1    # ... the learning rate factor lr_fac: lr_new = lr_old*lr_fac
DEFAULT_ARGS.log_interval = 10  # seconds

# %% [markdown]
# ### 3.3 Main Training Function
#
# In the next function, implement the main loop for training the `MusicTaggerCNN` network.
# For training, you should use an early stopping training protocoll with patience, like we did in assignment 5.
# You can mostly copy paste what you programmed there.
# However, this time also implement a learning rate schedule:
# After patience runs out, reload the best model and reduce the learning rate using the `lr_fac`: `lr_new = lr_old*lr_fac` and reset patience.
# This is done `arg.refinement` times (we call restarting the training with a reduced training rate a refinement run in this context).
# To update the learning rate of the optimizer you can use the following code snippet:
#
# ```
# for param_group in optimizer.param_groups:
#         param_group['lr'] = lr
# ```
#
#
# Write the network model to a file, whenever a better validation loss was achieved. If `load_model` is a filename, load the provided file, if it is set to true, load the last trained model (same behaviour as in assignment 5).
# As optimizer use `torch.optim.Adam`, the default parameters, except learning rate, should be fine.
#
# **Note: don't forget to reload the best model after training finishes!**
#
# **Implement the missing code parts** in the code cell below.

# %%
# main training loop, start with your implementation from the last assignment and modify to accompany 
# the leraning rate scedule.

def train_cnn(smoke_test=False, load_model=False, args=DEFAULT_ARGS):
    """
    Run CNN training using the datasets.
    :param smoke_test: bool, run a quick pseudo training to check if everything works
    :param load_model: bool or string, load the last trained model (if set to True), or the model in file (string)
    :param args: hyperparameters for training
    :return: trained model
    """
    if smoke_test:  # set hyperparameters to run a quick pseudo training...
        max_epochs = 2
        use_train_feats = train_feats[:2]
        use_valid_feats = valid_feats[:2]
        use_test_feats = test_feats[:2]
    else:
        max_epochs = args.max_epochs
        use_train_feats = train_feats
        use_valid_feats = valid_feats
        use_test_feats = test_feats
    
    # 1) setup pytorch
    # 2) create model and optimizer, use Adam
    # 3) setup datasets and loaders for training, evaluation and testing
    # YOUR CODE HERE
    # setup pytorch
    use_cuda = args.use_cuda and torch.cuda.is_available()
    torch.manual_seed(args.seed)
    args.device = torch.device("cuda" if use_cuda else "cpu")
    
    from torch.optim import Adam
    
    model = MusicTaggerCNN().to(args.device)
    optimizer = Adam(model.parameters(), lr=args.lr)
    
    # setup our datasets for training, evaluation and testing
    kwargs = {'num_workers': 2, 'pin_memory': True} if use_cuda else {'num_workers': 0}
    train_loader = torch.utils.data.DataLoader(MagnaSet(use_train_feats, train_targs),
                                               batch_size=args.batch_size, shuffle=True, **kwargs)
    valid_loader = torch.utils.data.DataLoader(MagnaSet(use_valid_feats, valid_targs),
                                               batch_size=args.batch_size, shuffle=False, **kwargs)
    test_loader = torch.utils.data.DataLoader(MagnaSet(use_test_feats, test_targs),
                                              batch_size=args.batch_size, shuffle=False, **kwargs)
    
    # find model filename for last run, and next free filename for model
    model_cnt = 0
    model_path = "/content/drive/MyDrive/audio/"
    new_model_file = os.path.join(model_path + CNN_MODEL_NAME + str(model_cnt) + '.model')
    last_model_file = None
    while os.path.exists(new_model_file):
        model_cnt += 1
        last_model_file = new_model_file
        new_model_file = os.path.join(CNN_MODEL_NAME + str(model_cnt) + '.model')
    if load_model is None or not load_model:  # let's train
        # train model for max_epochs epochs, output loss after log_intervall seconds.
        # for each epoch run once on validation set, 
        # write model to disk if validation loss decreased
        # if validation loss increased, check for early stopping with patience and refinements
        # after model is trained, perform a run on test set and output loss (don't forget to reload best model!)
        
        # YOUR CODE HERE
        best_valid_loss = 9999.  # let's init it with something really large - loss will be << 1 usually
        cur_patience = args.patience  # we keep track of our patience here.
        cur_refinement = args.refinement
        refine = True
        print('Training CNN...')
        start_t = get_time()
        
        while(refine):
            for epoch in range(max_epochs):
                print(epoch)
                train_epoch_cnn(model, train_loader, optimizer, args)
            
                valid_loss = test_cnn(model, valid_loader, args)
            
                if((get_time() - start_t) > args.log_interval):
                    print("validation loss is: " + str(valid_loss) )
            
                if(valid_loss < best_valid_loss):
                    if(smoke_test == False):
                        torch.save(model, new_model_file)
                    best_valid_loss = valid_loss
                    cur_patience = args.patience
                else:
                    if(cur_patience <= 0):
                        print("out of patience")

                        if(cur_refinement > 0 and smoke_test == False):
                            print("restarting training")
                            for param_group in optimizer.param_groups:
                                last_lr = param_group['lr']
                                param_group['lr'] = last_lr * args.lr_fac
                            model = torch.load(new_model_file)
                            cur_refinement -= 1
                            cur_patience = args.patience
                        else:
                            refine = False

                        break
                    else:
                        print("training on, epoch: " + str(epoch))
                        #print(cur_patience)
                        cur_patience = cur_patience - 1
                    
            
        print('Trainig took: {:.2f}s for {} epochs'.format(get_time()-start_t, epoch))
        
        print('Testing...')
        # Call test_cnn using the test_loader to calculate the loss on the test dataset
        # YOUR CODE HERE
        if(smoke_test == False):
          model = torch.load(new_model_file)
        
        test_loss = test_cnn(model, test_loader, args)
        print("Testing loss is: " + str(test_loss))
        
    else:  # we should just load a model...
        if not isinstance(load_model, str) or not os.path.exists(load_model):
            load_model = last_model_file
        if load_model is None or not os.path.exists(load_model):
            print('Model file not found, unable to load...')
        else:
            model.load_state_dict(torch.load(load_model, map_location=args.device))
            print("Model file loaded: {}".format(load_model))
    
    return model

# %% [markdown]
# Run the smoke test first, to make sure everything is ok:

# %%
# tests

model = train_cnn(smoke_test=True)  # just a quick run to check everything is working

print('All tests successful!')
# Out:
# Training CNN...
# 0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# [0/2 (0%)]	loss: 0.818711, took 0.42s
# Average eval loss: 151.9706
#
# 1
# [0/2 (0%)]	loss: 0.314694, took 0.19s
# Average eval loss: 179.6016
#
# training on, epoch: 1
# 0
# [0/2 (0%)]	loss: 0.192027, took 0.17s
# Average eval loss: 160.4702
#
# training on, epoch: 0
# 1
# [0/2 (0%)]	loss: 0.058770, took 0.18s
# Average eval loss: 115.8791
#
# 0
# [0/2 (0%)]	loss: 0.070437, took 0.17s
# Average eval loss: 112.8310
#
# 1
# [0/2 (0%)]	loss: 0.074800, took 0.18s
# Average eval loss: 113.3354
#
# training on, epoch: 1
# 0
# [0/2 (0%)]	loss: 0.043529, took 0.17s
# Average eval loss: 201.7034
#
# training on, epoch: 0
# 1
# [0/2 (0%)]	loss: 0.016016, took 0.17s
# Average eval loss: 176.6348
#
# training on, epoch: 1
# 0
# [0/2 (0%)]	loss: 0.007465, took 0.18s
# Average eval loss: 146.8178
#
# out of patience
# Trainig took: 5.77s for 0 epochs
# Testing...
# Average eval loss: 88.0925
#
# Testing loss is: 88.09245300292969
# All tests successful!

# %% [markdown]
# ### 3.4 Train Run
# Now that everything works, run the training for real.
# Execute the next cells to start a network training. Be aware that on JupyterHub, **a full training run will take around 24h.**
# As mentioned in the beginning of the notebook, you are free to run the notebook on CUDA enabled infrastructure e.g. on google colab, on which the training will run much faster.
#
# **ATTENTION**: For the submitted version, we only want to load the already trained model, so you have to set the switch below (SUBMISSION) to `True`! Additionally, make sure no new training is started when executing the final version before submission!!

# %%
SUBMISSION = False

# %%
#ignore this cell...

# %%
if not SUBMISSION:
    model = train_cnn()
else:
    model = train_cnn(load_model=True)
    # you can set a specific model file for submission, if you trained multiple models using e.g.:
    # load_model='best_cnn_adt.model'
# Out:
# Training CNN...
# 0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# [720/1287 (56%)]	loss: 0.208143, took 10.24s
# [945/1287 (97%)]	loss: 0.141721, took 7.19s
# Average eval loss: 11.9134
#
# validation loss is: 11.91336084667005
# 1
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type MusicTaggerCNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# [720/1287 (56%)]	loss: 0.192781, took 10.11s
# [945/1287 (97%)]	loss: 0.139244, took 7.22s
# Average eval loss: 9.8193
#
# validation loss is: 9.819340856451737
# 2
# [720/1287 (56%)]	loss: 0.174922, took 10.14s
# [945/1287 (97%)]	loss: 0.179155, took 7.26s
# Average eval loss: 9.5959
#
# validation loss is: 9.595910423680357
# 3
# [720/1287 (56%)]	loss: 0.207793, took 10.18s
# [945/1287 (97%)]	loss: 0.166007, took 7.28s
# Average eval loss: 10.4428
#
# validation loss is: 10.442817637794896
# training on, epoch: 3
# 4
# [720/1287 (56%)]	loss: 0.169679, took 10.16s
# [945/1287 (97%)]	loss: 0.221884, took 7.30s
# Average eval loss: 9.2094
#
# validation loss is: 9.20939678894846
# 5
# [720/1287 (56%)]	loss: 0.167849, took 10.22s
# [945/1287 (97%)]	loss: 0.185895, took 7.31s
# Average eval loss: 9.1148
#
# validation loss is: 9.11476883135344
# 6
# [720/1287 (56%)]	loss: 0.208327, took 10.20s
# [945/1287 (97%)]	loss: 0.172732, took 7.30s
# Average eval loss: 10.3959
#
# validation loss is: 10.39586739791067
# training on, epoch: 6
# 7
# [720/1287 (56%)]	loss: 0.181341, took 10.20s
# [945/1287 (97%)]	loss: 0.177971, took 7.30s
# Average eval loss: 9.3416
#
# validation loss is: 9.341623205887643
# training on, epoch: 7
# 8
# [720/1287 (56%)]	loss: 0.178719, took 10.21s
# [945/1287 (97%)]	loss: 0.193495, took 7.29s
# Average eval loss: 11.2649
#
# validation loss is: 11.264900508679842
# training on, epoch: 8
# 9
# [720/1287 (56%)]	loss: 0.171212, took 10.21s
# [945/1287 (97%)]	loss: 0.171136, took 7.31s
# Average eval loss: 9.1314
#
# validation loss is: 9.131427162571958
# out of patience
# restarting training
# 0
# [720/1287 (56%)]	loss: 0.189957, took 10.20s
# [945/1287 (97%)]	loss: 0.160220, took 7.29s
# Average eval loss: 8.7952
#
# validation loss is: 8.795173795599686
# 1
# [720/1287 (56%)]	loss: 0.180968, took 10.21s
# [945/1287 (97%)]	loss: 0.189459, took 7.30s
# Average eval loss: 8.7610
#
# validation loss is: 8.760970115661621
# 2
# [720/1287 (56%)]	loss: 0.149937, took 10.20s
# [945/1287 (97%)]	loss: 0.181359, took 7.30s
# Average eval loss: 8.7809
#
# validation loss is: 8.780869584334525
# training on, epoch: 2
# 3
# [720/1287 (56%)]	loss: 0.213678, took 10.19s
# [945/1287 (97%)]	loss: 0.191377, took 7.30s
# Average eval loss: 8.7745
#
# validation loss is: 8.774468923869886
# training on, epoch: 3
# 4
# [720/1287 (56%)]	loss: 0.179452, took 10.20s
# [945/1287 (97%)]	loss: 0.183068, took 7.29s
# Average eval loss: 8.7765
#
# validation loss is: 8.776549088327508
# training on, epoch: 4
# 5
# [720/1287 (56%)]	loss: 0.197301, took 10.21s
# [945/1287 (97%)]	loss: 0.233668, took 7.29s
# Average eval loss: 8.7733
#
# validation loss is: 8.773347603647332
# out of patience
# restarting training
# 0
# [720/1287 (56%)]	loss: 0.166458, took 10.21s
# [945/1287 (97%)]	loss: 0.189294, took 7.30s
# Average eval loss: 8.7704
#
# validation loss is: 8.770407074376157
# training on, epoch: 0
# 1
# [720/1287 (56%)]	loss: 0.185184, took 10.17s
# [945/1287 (97%)]	loss: 0.188421, took 7.29s
# Average eval loss: 8.7683
#
# validation loss is: 8.768293681897616
# training on, epoch: 1
# 2
# [720/1287 (56%)]	loss: 0.165458, took 10.20s
# [945/1287 (97%)]	loss: 0.201207, took 7.29s
# Average eval loss: 8.7833
#
# validation loss is: 8.783333979154888
# training on, epoch: 2
# 3
# [720/1287 (56%)]	loss: 0.164618, took 10.18s
# [945/1287 (97%)]	loss: 0.189214, took 7.30s
# Average eval loss: 8.7798
#
# validation loss is: 8.77975092436138
# out of patience
# Trainig took: 370.38s for 3 epochs
# Testing...
# Average eval loss: 8.8335
#
# Testing loss is: 8.833489991930634

# %% [markdown]
# ## Task 4: Inference on Test Data (5 Points)
# Now that we have a trained model, we want to use it to do audio tagging. In order to do this, we have to apply the model on a the extracted features.
# Since we are interested in calculating the area-under-curve (AUC) for the receiver operating characteristic (ROC, true-positive-rate v.s. false-positive-rate plot for different detection thresholds), return the raw class probabilities (direct sigmoid outputs), instead of the thresholded classes.

# %%
def extract_tags_for_all(model, feats, args=DEFAULT_ARGS):
    detection_list = []
    # YOUR CODE HERE
    
    #print(feats.shape)
    
    for f in feats: 
      detection_list.append(inference_cnn(model, f, args))

    return np.asarray(detection_list)

# %%
t1 = get_time()
detected_tags = extract_tags_for_all(model, test_feats)
print("Time used for tag estimation: {:.1f} seconds.".format(get_time()-t1))
test_targs = np.asarray(test_targs)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Time used for tag estimation: 1.8 seconds.

# %%
# tests

assert len(detected_tags) == len(test_feats), "generate detections for all test samples!!"

assert 0.0 < np.median(detected_tags) < 1.0, "return sigmoid outputs, without applying a threshold!!"

print('All tests successful!')
# Out:
# All tests successful!

# %% [markdown]
# ### 4.1 Plot Prediction
# Create a visual representation of the predicted class activations for an example of the test data, and compare it to the true labels.

# %%
# visual inspection, plot an activation vector v.s. the true labels as a bar chart or similar.

import matplotlib.pyplot as plt

sample_idx = 15  # you can play around with this value :)

activation = detected_tags[sample_idx]
true_labels = test_targs[sample_idx]

# YOUR CODE HERE
figure, axis = plt.subplots(figsize=(20,10))

plt.plot(range(len(true_labels)), activation, label="Activation Vectors")
plt.bar(range(len(true_labels)), height=1.0, width=0.05, color='green')

axis.set_xticks(range(len(true_labels)))
axis.set_xticklabels(class_names, rotation = 90)

plt.show()

# %%
#ignore this cell

# %% [markdown]
# ## Task 5: Evaluation (10 Points)
#
# ### 5.1 AOC of ROC
#
# Use the detections and targets of the test set to estimate the performance of the trained network using area-under-curve of the ROC (you can use the sklearn implementations).

# %%
from sklearn.metrics import roc_curve, auc

# %%
def calc_roc_auc(true_tags, detected_tags, num_classes):
    # Calculate true positive (tpr) and false positive rates (fpr) for applicable thresholds and compute 
    # ROC curve and area under ROC curve. 
    # Since we have a multiclass setup, use micro-average evaluation: count true and false positives for all 
    # classes and all instances, and then calculate the metrics.
    # To get an exhaustive list of thresholds that will result in different values for tpr and fpr, it is most 
    # efficient to use unique values of the detected probabilities. However, you do not have to worry about the 
    # thresholds if you use the sklearn functions.
    
    # YOUR CODE HERE
    true_tags = true_tags.astype(np.int)

    micro_fpr, micro_tpr, n = roc_curve(true_tags.ravel(), detected_tags.ravel())

    micro_roc_auc = auc(micro_fpr, micro_tpr)

    # return area under curve, true positive rates, and false positive rates (we will use them for plotting)
    return micro_roc_auc, micro_tpr, micro_fpr

# %%
final_score, micro_tpr, micro_fpr = calc_roc_auc(test_targs, detected_tags, len(class_names))
print(f'Final AOC-ROC score of trained model: {final_score}')
# Out:
# Final AOC-ROC score of trained model: 0.8008112142390256
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]

# %%
# tests

# you should be able to achieve this AOC score
assert final_score > 0.8


print('All tests successful!')
# Out:
# All tests successful!

# %% [markdown]
# ### 5.2 Plot ROC
#
# Plot an ROC curve for micro-average evaluation of the test detections. The values for the test detections should have been saved in `final_score`, `micro_tpr`, and `micro_fpr` in the previous cells.

# %%
# YOUR CODE HERE
plt.figure()
plt.plot([0,1], [0,1], linestyle='solid')

plt.plot(micro_fpr, micro_tpr, label=('ROC: {:.3f}'.format(final_score)))
plt.xlabel('FP Rate')
plt.ylabel('TP Rate')
plt.legend()
plt.show()

# %%
# ingore this cell

# %% [markdown]
# ### 5.3 Conclusion
# Compare your results to the numbers reported by Choi et al. \[2016\] and comment on your main findings.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# The result of the ROC curve I got is 0.8008, which is worse than the results of the Choi paper (0.852, 0.894, 0.890), but still ok and comparable. With a bigger infrastructure, more ram and a 48 batch_size (that I had to lower due to RAM crashes) and the use of all of the data, I should be able to achieve a higher score with this network.

# %% [markdown]
# ## Congratulations, you are done!
#
# Reminder:
# Before you turn this assignment in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
